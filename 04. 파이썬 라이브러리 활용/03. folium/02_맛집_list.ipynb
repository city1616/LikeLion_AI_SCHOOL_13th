# %% [markdown]
# ### 나의 맛집 리스트
# * 새들러 하우스 가로수길
#   * 37.519342367005656, 127.02490880945011
# * 카페 노티드 한남
#   * 37.53482467940994, 127.00084171852781
# * 랜드스도넛 연남점
#   * 37.5620028628832, 126.92413891666314
# * 모터시티바이매니멀 본점
#   * 37.5340066100028, 126.98943966054081
# * 패션5
#   * 37.53870776467558, 127.00201893044547
# * 카페 키츠네 서울
#   * 37.51962164469669, 127.0227621153202
# * 스킬렛스테이크하우스
#   * 37.52221082457378, 127.02369243026874
# * 더앨리 가로수길점
#   * 37.522872307888754, 127.0224232038378

# %%
import folium

# %%
map = folium.Map(location = [37.53403977051825, 126.97510544012256], zoom_start = 12)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
# Marker 표시
folium.Marker([37.519342367005656, 127.02490880945011],
              popup = "새들러 하우스 가로수길",
              icon = folium.Icon(color = 'purple', icon = 'star')).add_to(map)
folium.Marker([37.53482467940994, 127.00084171852781],
              popup = "카페 노티드 한남",
              icon = folium.Icon(color = 'purple', icon = 'star')).add_to(map)
folium.Marker([37.5620028628832, 126.92413891666314],
              popup = "랜드스도넛 연남점",
              icon = folium.Icon(color = 'purple', icon = 'star')).add_to(map)
folium.Marker([37.5340066100028, 126.98943966054081],
              popup = "모터시티바이매니멀 본점",
              icon = folium.Icon(color = 'purple', icon = 'star')).add_to(map)
folium.Marker([37.53870776467558, 127.00201893044547],
              popup = "패션5",
              icon = folium.Icon(color = 'purple', icon = 'star')).add_to(map)
folium.Marker([37.51962164469669, 127.0227621153202],
              popup = "카페 키츠네 서울",
              icon = folium.Icon(color = 'purple', icon = 'star')).add_to(map)
folium.Marker([37.52221082457378, 127.02369243026874],
              popup = "스킬렛스테이크하우스",
              icon = folium.Icon(color = 'purple', icon = 'star')).add_to(map)
folium.Marker([37.522872307888754, 127.0224232038378],
              popup = "더앨리 가로수길점",
              icon = folium.Icon(color = 'purple', icon = 'star')).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
map.save("맛집_list.html")
