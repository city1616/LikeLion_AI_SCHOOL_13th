# %% [markdown]
# ### 2021_09_16

# %% [markdown]
# ## pandas basic 실습

# %%
myfood = ['banana', 'apple', 'candy']
print(myfood[0])
print(myfood[1])
print(myfood[2])
# Out:
# banana
# apple
# candy

# %%
for item in myfood :
    print(item)
# Out:
# banana
# apple
# candy

# %%
dict1 = {"one" : "하나", "two" : "둘", "three" : "셋"}
dict2 = {1 : "하나", 2 : "둘", 3 : "셋"}
dict3 = {"col" : [1, 2, 3], "col2" : ['a', 'b', 'c']}

# %%
print(dict1)
print(dict2)
print(dict3)
# Out:
# {'one': '하나', 'two': '둘', 'three': '셋'}
# {1: '하나', 2: '둘', 3: '셋'}
# {'col': [1, 2, 3], 'col2': ['a', 'b', 'c']}

# %% [markdown]
# ### pandas module 불러오기

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
print("pandas version :", pd.__version__)
# Out:
# pandas version : 1.3.2

# %%
from pandas import Series, DataFrame

# %%
## ___ = Series([1000, 14000, 3000, 30000, 10000])
score = Series([1000, 14000, 3000, 30000, 10000])
print(score)
# Out:
# 0     1000
# 1    14000
# 2     3000
# 3    30000
# 4    10000
# dtype: int64

# %%
type(score)
# Out:
# pandas.core.series.Series

# %%
# Series 인덱스 확인
print(score.index)
# 인덱스를 리스트 자료형으로 변경 후, 확인하기
print(list(score.index))
# Series 값 확인
print(score.values)

# score type 확인
print(type(score.index))
print(type(list(score.index)))
print(type(score.values))
# Out:
# RangeIndex(start=0, stop=5, step=1)
# [0, 1, 2, 3, 4]
# [ 1000 14000  3000 30000 10000]
# <class 'pandas.core.indexes.range.RangeIndex'>
# <class 'list'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ## 판다스 시리즈 인덱스 지정

# %%
# 인덱스(index) 속성 이용
score = Series([1000, 14000, 3000], index = ['2019-05-01', '2019-05-02', '2019-05-03'])
print(score)
# Out:
# 2019-05-01     1000
# 2019-05-02    14000
# 2019-05-03     3000
# dtype: int64

# %%
# 실습 1-1 Series를 만들기(자료형으로 만들기)
score = Series(['a', 'b', 'c'])
print(score)
# 실습 1-2 index 넣어보기
score_idx = Series(['a', 'b', 'c'], index = ['2021-09-16', '2021-09-17', '2021-09-18'])
print(score_idx)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object
# 2021-09-16    a
# 2021-09-17    b
# 2021-09-18    c
# dtype: object

# %%
for idx in score.index :
    print(idx)
# Out:
# 0
# 1
# 2

# %%
for value in score.values :
    print(value)
# Out:
# a
# b
# c

# %%
# date_range를 이용한 인덱스 지정
idx = pd.date_range(start = "2021-01-01", end = "2021-01-03").tolist()

score_idx = Series(['a', 'b', 'c'], index = idx)

print(score_idx)
# Out:
# 2021-01-01    a
# 2021-01-02    b
# 2021-01-03    c
# dtype: object

# %% [markdown]
# ### 두 팀의 팀점수 합산해보기
# * 길동팀의 3일간의 점수와 toto팀의 3일간의 점수

# %%
gildong = Series([1500, 3000, 2500], index = ['2019-05-01', '2019-05-02', '2019-05-03'])
toto = Series([3000, 3000, 2000], index = ['2019-05-01', '2019-05-03', '2019-05-02'])
print(gildong + toto)
# Out:
# 2019-05-01    4500
# 2019-05-02    5000
# 2019-05-03    5500
# dtype: int64

# %%
date_idx = pd.date_range(start = "2021-01-01", end = "2021-01-03").tolist()
A = Series([1000, 1000, 1000], index = date_idx)
B = Series([2000, 2000, 2000], index = date_idx)
print(A + B)
# Out:
# 2021-01-01    3000
# 2021-01-02    3000
# 2021-01-03    3000
# dtype: int64

# %% [markdown]
# ### 데이터는 3개월 날짜 1부터 90까지 idx를 3개월 날짜로 지정하기 (1월~3월)

# %%
d_idx = pd.date_range(start = "2021-01-01", end = "2021-03-31").tolist()
date = Series(range(1, 91), index = d_idx)
print(date)
# Out:
# 2021-01-01     1
# 2021-01-02     2
# 2021-01-03     3
# 2021-01-04     4
# 2021-01-05     5
#               ..
# 2021-03-27    86
# 2021-03-28    87
# 2021-03-29    88
# 2021-03-30    89
# 2021-03-31    90
# Length: 90, dtype: int64

# %% [markdown]
# ## 데이터 프레임의 이해
# * 데이터 프레임의 객체를 생성하는 가장 간단한 방법은 딕셔너리를 이용하는 방법
# * 데이터 프레임은 Series의 결합으로 이루어진 것으로 생각할 수 있음.
# * pandas의 대표적인 기본 자료형이다.
# * Seaborn 데이터(load_dataset() - pandas)
#     * seaborn에 들어가는 기본적인 데이터 자료형이 pandas이다.
# * plotly에서도 pandas 호환
# * DataFrame 함수를 이용하여 객체 생성이 가능하다.

# %%
from pandas import DataFrame

# %%
dat = {'col1' : [1, 2, 3, 4],
      'col2' : [10, 20, 30, 40],
      'col3' : ['A', 'B', 'C', 'D']}
df = DataFrame(dat)
df
# Out:
#    col1  col2 col3
# 0     1    10    A
# 1     2    20    B
# 2     3    30    C
# 3     4    40    D

# %%
idx_date = pd.date_range(start = "2021-09-01", end = "2021-09-04").tolist()
dat = {'col1' : [1, 2, 3, 4],
      'col2' : [10, 20, 30, 40],
      'col3' : ['A', 'B', 'C', 'D']}
df = DataFrame(dat, index = idx_date)
df
# Out:
#             col1  col2 col3
# 2021-09-01     1    10    A
# 2021-09-02     2    20    B
# 2021-09-03     3    30    C
# 2021-09-04     4    40    D

# %% [markdown]
# ### 네 팀의 5일간의 팀별 점수
# * 팀은 toto, gildong, apple, catanddog 팀이다.

# %%
from pandas import DataFrame

team_score = {"toto" : [1500, 3000, 5000, 7000, 5500],
             "apple" : [4000, 5000, 6000, 5500, 4500],
             "gildong" : [2000, 2500, 3000, 4000, 3000],
             "catanddog" : [7000, 5000, 3000, 5000, 4000]}

team_df = DataFrame(team_score)
team_df
# Out:
#    toto  apple  gildong  catanddog
# 0  1500   4000     2000       7000
# 1  3000   5000     2500       5000
# 2  5000   6000     3000       3000
# 3  7000   5500     4000       5000
# 4  5500   4500     3000       4000

# %% [markdown]
# ### toto팀의 점수 확인
# * 팀별 컬럼명을 이용하여 접근이 가능하다.

# %%
team_df['toto']
# Out:
# 0    1500
# 1    3000
# 2    5000
# 3    7000
# 4    5500
# Name: toto, dtype: int64

# %%
team_df[['toto']]
# Out:
#    toto
# 0  1500
# 1  3000
# 2  5000
# 3  7000
# 4  5500

# %%
# 두 개의 열 선택 - 잘못된 선택
# team_df['catanddog', 'toto']

# %%
# 두 개의 열 선택 - 해결
team_df[['catanddog', 'toto']]
# Out:
#    catanddog  toto
# 0       7000  1500
# 1       5000  3000
# 2       3000  5000
# 3       5000  7000
# 4       4000  5500

# %%
# 두 개의 열 선택
# team_df.loc[]
# team_df.iloc[]

# %% [markdown]
# ### loc와 iloc를 이용한 접근
# * loc는 데이터 프레임의 컬럼명(인덱스)를 사용하여 데이터를 추출한다.
# * iloc는 데이터 프레임의 데이터 순서(번호)를 사용하여 데이터를 추출한다.(시작번호 : 0)
# * loc[행, 열] 접근

# %% [markdown]
# ### DataFrame.loc[ ]

# %%
team_df
# Out:
#    toto  apple  gildong  catanddog
# 0  1500   4000     2000       7000
# 1  3000   5000     2500       5000
# 2  5000   6000     3000       3000
# 3  7000   5500     4000       5000
# 4  5500   4500     3000       4000

# %%
# team_df.loc[행선택, 열선택]
team_df.loc[:, "apple":"catanddog"]
# Out:
#    apple  gildong  catanddog
# 0   4000     2000       7000
# 1   5000     2500       5000
# 2   6000     3000       3000
# 3   5500     4000       5000
# 4   4500     3000       4000

# %%
# team_df.loc[행선택, 열선택]
team_df.loc[[0, 2, 4], ["toto", "gildong"]]
# Out:
#    toto  gildong
# 0  1500     2000
# 2  5000     3000
# 4  5500     3000

# %%
# team_df.loc[행선택, 열선택]
team_df.loc[:, ["gildong"]]
# Out:
#    gildong
# 0     2000
# 1     2500
# 2     3000
# 3     4000
# 4     3000

# %%
# team_df.loc[행선택, 열선택]
team_df.loc[:, "gildong":"catanddog"]
# Out:
#    gildong  catanddog
# 0     2000       7000
# 1     2500       5000
# 2     3000       3000
# 3     4000       5000
# 4     3000       4000

# %%
# team_df.loc[행선택, 열선택]
team_df.loc[:, ["gildong", "catanddog"]]
# Out:
#    gildong  catanddog
# 0     2000       7000
# 1     2500       5000
# 2     3000       3000
# 3     4000       5000
# 4     3000       4000

# %%
# team_df.loc[행선택, 열선택]
team_df.loc[1:3, "toto" : "gildong"]
# Out:
#    toto  apple  gildong
# 1  3000   5000     2500
# 2  5000   6000     3000
# 3  7000   5500     4000

# %%
# team_df.loc[행선택, 열선택]
# 1행, 3행 선택하기
team_df.loc[[1, 3], :]
# Out:
#    toto  apple  gildong  catanddog
# 1  3000   5000     2500       5000
# 3  7000   5500     4000       5000

# %%
# team_df.loc[행선택, 열선택]
# apple, catanddog 선택
team_df.loc[:, ["apple", "catanddog"]]
# Out:
#    apple  catanddog
# 0   4000       7000
# 1   5000       5000
# 2   6000       3000
# 3   5500       5000
# 4   4500       4000

# %%
# team_df.loc[행선택, 열선택]
# 1, 3행, apple, catanddog 선택
team_df.loc[[2, 4], ["apple", "catanddog"]]
# Out:
#    apple  catanddog
# 2   6000       3000
# 4   4500       4000

# %%
team_df
# Out:
#    toto  apple  gildong  catanddog
# 0  1500   4000     2000       7000
# 1  3000   5000     2500       5000
# 2  5000   6000     3000       3000
# 3  7000   5500     4000       5000
# 4  5500   4500     3000       4000

# %%
# apple, gildong, catanddog의 2, 3행 선택
team_df.loc[2 : 3, "apple" : "catanddog"]
# Out:
#    apple  gildong  catanddog
# 2   6000     3000       3000
# 3   5500     4000       5000

# %%
# apple, gildong, catanddog의 2, 3행 선택
# catanddog가 마지막 column이기 때문에 생략 가능
team_df.loc[2 : 3, "apple" :]
# Out:
#    apple  gildong  catanddog
# 2   6000     3000       3000
# 3   5500     4000       5000

# %% [markdown]
# ### DataFrame.iloc[ ]

# %%
# 전체 선택
team_df.iloc[ : , : ]
# Out:
#    toto  apple  gildong  catanddog
# 0  1500   4000     2000       7000
# 1  3000   5000     2500       5000
# 2  5000   6000     3000       3000
# 3  7000   5500     4000       5000
# 4  5500   4500     3000       4000

# %%
# 0행 선택
team_df.iloc[[0], :]
# Out:
#    toto  apple  gildong  catanddog
# 0  1500   4000     2000       7000

# %%
# 2, 3, 4행 toto 선택
team_df.iloc[2 : 5, 0 : 1]
# Out:
#    toto
# 2  5000
# 3  7000
# 4  5500

# %%
# 2, 3, 4행 toto 선택
team_df.iloc[[2, 3, 4], 0 : 1]
# Out:
#    toto
# 2  5000
# 3  7000
# 4  5500

# %%
# apple, gildong의 1 ~ 4행 선택
team_df.iloc[1 : 5, 1 : 3]
# Out:
#    apple  gildong
# 1   5000     2500
# 2   6000     3000
# 3   5500     4000
# 4   4500     3000

# %%
# apple, gildong, catanddog 열 선택
team_df.iloc[:, 1:]
# Out:
#    apple  gildong  catanddog
# 0   4000     2000       7000
# 1   5000     2500       5000
# 2   6000     3000       3000
# 3   5500     4000       5000
# 4   4500     3000       4000

# %%
# apple, gildong 열의 0 ~ 2 행 선택
team_df.iloc[0 : 3, 1 : 3]
# Out:
#    apple  gildong
# 0   4000     2000
# 1   5000     2500
# 2   6000     3000

# %%
# apple, catanddog 열의 1 ~ 3행 선택
team_df.iloc[1 : 4, [1, 3]]
# Out:
#    apple  catanddog
# 1   5000       5000
# 2   6000       3000
# 3   5500       5000

# %%
# toto, apple 열의 1 ~ 3행 선택
team_df.iloc[1 : 4, 0 : 2]
# Out:
#    toto  apple
# 1  3000   5000
# 2  5000   6000
# 3  7000   5500

# %%
# toto, catanddog 열의 1, 2행 선택
team_df.iloc[1 : 3, [1, 3]]
# Out:
#    apple  catanddog
# 1   5000       5000
# 2   6000       3000

# %%
# toto, catanddog 열의 1, 2행 선택
team_df.iloc[1 : 3, 1 : 4: 2]
# Out:
#    apple  catanddog
# 1   5000       5000
# 2   6000       3000

# %%
idx_date = pd.date_range(start="2020-01-01",end="2020-01-05").tolist()
team_df.index = idx_date
team_df
# Out:
#             toto  apple  gildong  catanddog
# 2020-01-01  1500   4000     2000       7000
# 2020-01-02  3000   5000     2500       5000
# 2020-01-03  5000   6000     3000       3000
# 2020-01-04  7000   5500     4000       5000
# 2020-01-05  5500   4500     3000       4000

# %%
team_df.iloc[[0, 1, 2], :]
# Out:
#             toto  apple  gildong  catanddog
# 2020-01-01  1500   4000     2000       7000
# 2020-01-02  3000   5000     2500       5000
# 2020-01-03  5000   6000     3000       3000

# %%
team_df.loc['2020-01-01':'2020-01-03', :]
# Out:
#             toto  apple  gildong  catanddog
# 2020-01-01  1500   4000     2000       7000
# 2020-01-02  3000   5000     2500       5000
# 2020-01-03  5000   6000     3000       3000

# %%
team_df.iloc[0:3, :]
# Out:
#             toto  apple  gildong  catanddog
# 2020-01-01  1500   4000     2000       7000
# 2020-01-02  3000   5000     2500       5000
# 2020-01-03  5000   6000     3000       3000

# %%
idx_date = pd.date_range(start="2019-05-01",end="2019-05-05").tolist()
team_df.index = idx_date
team_df
# Out:
#             toto  apple  gildong  catanddog
# 2019-05-01  1500   4000     2000       7000
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000
# 2019-05-04  7000   5500     4000       5000
# 2019-05-05  5500   4500     3000       4000

# %%
print(team_df.loc[ '2019-05-02' ] ) # 19-05-02 일
print("-----------")
print(team_df.loc[ ['2019-05-02', '2019-05-03'] ]) # 5월 2일, 3일 
print("-----------")
print(team_df.loc[ '2019-05-02': ])  # 5월 2일 이후 전체 데이터 가져오기
# Out:
# toto         3000
# apple        5000
# gildong      2500
# catanddog    5000
# Name: 2019-05-02 00:00:00, dtype: int64
# -----------
#             toto  apple  gildong  catanddog
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000
# -----------
#             toto  apple  gildong  catanddog
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000
# 2019-05-04  7000   5500     4000       5000
# 2019-05-05  5500   4500     3000       4000

# %% [markdown]
# ### loc를 이용한 열에 접근

# %%
## 컬럼명 확인 
print(team_df.columns)
print("-----")
print(team_df.loc[:, 'toto'])   # 전체행, toto팀 
print("-----")
print(team_df.loc[:, ['toto', 'gildong'] ])   # 전체행, toto, gildong팀
print("-----")
print(team_df.loc[:, 'toto': ])   # 전체행, toto 부터 끝까지
# Out:
# Index(['toto', 'apple', 'gildong', 'catanddog'], dtype='object')
# -----
# 2019-05-01    1500
# 2019-05-02    3000
# 2019-05-03    5000
# 2019-05-04    7000
# 2019-05-05    5500
# Name: toto, dtype: int64
# -----
#             toto  gildong
# 2019-05-01  1500     2000
# 2019-05-02  3000     2500
# 2019-05-03  5000     3000
# 2019-05-04  7000     4000
# 2019-05-05  5500     3000
# -----
#             toto  apple  gildong  catanddog
# 2019-05-01  1500   4000     2000       7000
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000
# 2019-05-04  7000   5500     4000       5000
# 2019-05-05  5500   4500     3000       4000

# %% [markdown]
# ### iloc 속성을 이용한 행, 열 데이터 접근하기

# %%
print(team_df.iloc[0])      # 첫번째 행 접근
print("------")
print(team_df.iloc[ [0,1] ])  # 첫번째 두번째 행 접근
print("------")
print(team_df.iloc[ 0:3:1] )  # 첫번째부터 세번째 행 접근
print("------")
range_num = list(range(0,3,1))
print(team_df.iloc[ range_num ] )  # 첫번째부터 세번째 행 접근
# Out:
# toto         1500
# apple        4000
# gildong      2000
# catanddog    7000
# Name: 2019-05-01 00:00:00, dtype: int64
# ------
#             toto  apple  gildong  catanddog
# 2019-05-01  1500   4000     2000       7000
# 2019-05-02  3000   5000     2500       5000
# ------
#             toto  apple  gildong  catanddog
# 2019-05-01  1500   4000     2000       7000
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000
# ------
#             toto  apple  gildong  catanddog
# 2019-05-01  1500   4000     2000       7000
# 2019-05-02  3000   5000     2500       5000
# 2019-05-03  5000   6000     3000       3000

# %%
print(team_df.iloc[0])
print(type(team_df.iloc[0]))
# Out:
# toto         1500
# apple        4000
# gildong      2000
# catanddog    7000
# Name: 2019-05-01 00:00:00, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
print(team_df.iloc[1 : 2, :])
# Out:
#             toto  apple  gildong  catanddog
# 2019-05-02  3000   5000     2500       5000

# %% [markdown]
# ### 일반 통계
# * 합
# * 평균
# * 표준편차
# * 기타..

# %%
# 합 : .sum()
print(team_df.sum())
print(team_df.sum(axis = 0)) # axis = 0(index 합), 1(column 합)
print(team_df.sum(axis = 1))
# Out:
# toto         22000
# apple        25000
# gildong      14500
# catanddog    24000
# dtype: int64
# toto         22000
# apple        25000
# gildong      14500
# catanddog    24000
# dtype: int64
# 2019-05-01    14500
# 2019-05-02    15500
# 2019-05-03    17000
# 2019-05-04    21500
# 2019-05-05    17000
# dtype: int64

# %% [markdown]
# ### 실습 4-2 통계량 구하기

# %%
# 평균 : mean()
team_df.mean()
# Out:
# toto         4400.0
# apple        5000.0
# gildong      2900.0
# catanddog    4800.0
# dtype: float64

# %%
# 표준편차 : std()
team_df.std()
# Out:
# toto         2162.174831
# apple         790.569415
# gildong       741.619849
# catanddog    1483.239697
# dtype: float64

# %%
# 요약값 : describe()
team_df.describe()
# Out:
#               toto        apple      gildong    catanddog
# count     5.000000     5.000000     5.000000     5.000000
# mean   4400.000000  5000.000000  2900.000000  4800.000000
# std    2162.174831   790.569415   741.619849  1483.239697
# min    1500.000000  4000.000000  2000.000000  3000.000000
# 25%    3000.000000  4500.000000  2500.000000  4000.000000
# 50%    5000.000000  5000.000000  3000.000000  5000.000000
# 75%    5500.000000  5500.000000  3000.000000  5000.000000
# max    7000.000000  6000.000000  4000.000000  7000.000000

# %%
# 표준편차, 분산, 최대값, 최소값, 중앙값, 누적통계, 컬럼별 개수
print(team_df.std(), end = "\n\n")
print(team_df.var(), end = "\n\n")
print(team_df.max(), end = "\n\n")
print(team_df.min(), end = "\n\n")
print(team_df.median(), end = "\n\n")
print(team_df.cumsum(), end = "\n\n")
print(team_df.count(), end = "\n\n")
# Out:
# toto         2162.174831
# apple         790.569415
# gildong       741.619849
# catanddog    1483.239697
# dtype: float64
#
# toto         4675000.0
# apple         625000.0
# gildong       550000.0
# catanddog    2200000.0
# dtype: float64
#
# toto         7000
# apple        6000
# gildong      4000
# catanddog    7000
# dtype: int64
#
# toto         1500
# apple        4000
# gildong      2000
# catanddog    3000
# dtype: int64
#
# toto         5000.0
# apple        5000.0
# gildong      3000.0
# catanddog    5000.0
# dtype: float64
#
#              toto  apple  gildong  catanddog
# 2019-05-01   1500   4000     2000       7000
# 2019-05-02   4500   9000     4500      12000
# 2019-05-03   9500  15000     7500      15000
# 2019-05-04  16500  20500    11500      20000
# 2019-05-05  22000  25000    14500      24000
#
# toto         5
# apple        5
# gildong      5
# catanddog    5
# dtype: int64

# %%
# toto 열의 합
team_df['toto'].sum()
# Out:
# 22000

# %%
# toto, apple 열의 합
team_df[["toto", "apple"]].sum()
# Out:
# toto     22000
# apple    25000
# dtype: int64

# %%
team_df.count()
# Out:
# toto         5
# apple        5
# gildong      5
# catanddog    5
# dtype: int64

# %%
team_df.count().index
# Out:
# Index(['toto', 'apple', 'gildong', 'catanddog'], dtype='object')

# %%
team_df.count().values
# Out:
# array([5, 5, 5, 5])

# %% [markdown]
# ### apple과 catanddog의 sum(), mean(), std()

# %%
print(team_df[["apple", "catanddog"]].sum(), end = "\n\n")
print(team_df[["apple", "catanddog"]].mean(), end = "\n\n")
print(team_df[["apple", "catanddog"]].std(), end = "\n\n")
# Out:
# apple        25000
# catanddog    24000
# dtype: int64
#
# apple        5000.0
# catanddog    4800.0
# dtype: float64
#
# apple         790.569415
# catanddog    1483.239697
# dtype: float64

# %% [markdown]
# ### team_df의 sum()을 구하고 기존의 team_df에 추가해 보자.

# %%
team_df["row_sum"] = team_df.sum(axis = 1)
team_df
# Out:
#    toto  apple  gildong  catanddog  row_sum
# 0  1500   4000     2000       7000    14500
# 1  3000   5000     2500       5000    15500
# 2  5000   6000     3000       3000    17000
# 3  7000   5500     4000       5000    21500
# 4  5500   4500     3000       4000    17000

# %% [markdown]
# ### Titanic 데이터 셋으로 요약 보고서 작성

# %%
import seaborn as sns

t = sns.load_dataset("titanic")
t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# * t.columns : 컬럼명 확인
# * t.shape : 행과 열 확인
# * t.describe() : 통계량 확인
# * t.head() : 앞의 5행 보기
# * t.tail() : 뒤의 5행 보기

# %%
t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
team_df
# Out:
#    toto  apple  gildong  catanddog  row_sum
# 0  1500   4000     2000       7000    14500
# 1  3000   5000     2500       5000    15500
# 2  5000   6000     3000       3000    17000
# 3  7000   5500     4000       5000    21500
# 4  5500   4500     3000       4000    17000

# %%
team_df.columns
# Out:
# Index(['toto', 'apple', 'gildong', 'catanddog', 'row_sum'], dtype='object')

# %%
team_df.shape
# Out:
# (5, 5)

# %%
team_df.sort_values("row_sum", ascending = False)
# Out:
#    toto  apple  gildong  catanddog  row_sum
# 3  7000   5500     4000       5000    21500
# 2  5000   6000     3000       3000    17000
# 4  5500   4500     3000       4000    17000
# 1  3000   5000     2500       5000    15500
# 0  1500   4000     2000       7000    14500

# %%
team_df["row_mean"] = team_df.iloc[:, 0:4].mean(axis = 1)

# %%
team_df.row_mean.sort_values(ascending = False)
team_df
# Out:
#    toto  apple  gildong  catanddog  row_sum  row_mean
# 0  1500   4000     2000       7000    14500    3625.0
# 1  3000   5000     2500       5000    15500    3875.0
# 2  5000   6000     3000       3000    17000    4250.0
# 3  7000   5500     4000       5000    21500    5375.0
# 4  5500   4500     3000       4000    17000    4250.0

# %%
team_df.sort_values("row_mean", ascending = False)
# Out:
#    toto  apple  gildong  catanddog  row_sum  row_mean
# 3  7000   5500     4000       5000    21500    5375.0
# 2  5000   6000     3000       3000    17000    4250.0
# 4  5500   4500     3000       4000    17000    4250.0
# 1  3000   5000     2500       5000    15500    3875.0
# 0  1500   4000     2000       7000    14500    3625.0

# %%
# 자료형 - Series, DataFrame
# 행과 열을 선택 - loc, iloc
# date_range()
# 새로운 열을 추가 : __["새로운 컬럼명"] = ___
# 통계량 구하기 : [].sum(), mean(), std() 
# axis = 0(각 열의 최종합, 행들의 합)
# axis = 1(행의 합, column들의 합)
# 값을 정렬 sort_values()

# %%
team_df
# Out:
#    toto  apple  gildong  catanddog  row_sum  row_mean
# 0  1500   4000     2000       7000    14500    3625.0
# 1  3000   5000     2500       5000    15500    3875.0
# 2  5000   6000     3000       3000    17000    4250.0
# 3  7000   5500     4000       5000    21500    5375.0
# 4  5500   4500     3000       4000    17000    4250.0

# %% [markdown]
# ### 행의 합이 15000 이상인 값 찾기
# * 조건을 걸어 데이터 찾기

# %%
team_df[team_df.row_sum >= 15000]
# Out:
#    toto  apple  gildong  catanddog  row_sum  row_mean
# 1  3000   5000     2500       5000    15500    3875.0
# 2  5000   6000     3000       3000    17000    4250.0
# 3  7000   5500     4000       5000    21500    5375.0
# 4  5500   4500     3000       4000    17000    4250.0

# %%
team_df.loc[team_df.row_sum >= 15000, :]
# Out:
#    toto  apple  gildong  catanddog  row_sum  row_mean
# 1  3000   5000     2500       5000    15500    3875.0
# 2  5000   6000     3000       3000    17000    4250.0
# 3  7000   5500     4000       5000    21500    5375.0
# 4  5500   4500     3000       4000    17000    4250.0

# %% [markdown]
# * 조건을 2개를 걸어 데이터 찾기
#     * 행의 합이 15000 이상, 행의 평균이 4000 이상인 값 찾기

# %%
team_df.loc[(team_df.row_sum >= 15000) & (team_df.row_mean >= 4000), :]
# Out:
#    toto  apple  gildong  catanddog  row_sum  row_mean
# 2  5000   6000     3000       3000    17000    4250.0
# 3  7000   5500     4000       5000    21500    5375.0
# 4  5500   4500     3000       4000    17000    4250.0

# %% [markdown]
# * 5월 3일이상, row_sum이 15000이상

# %%
idx_date = pd.date_range(start="2019-05-01",end="2019-05-05").tolist()
team_df.index = idx_date
team_df
# Out:
#             toto  apple  gildong  catanddog  row_sum  row_mean
# 2019-05-01  1500   4000     2000       7000    14500    3625.0
# 2019-05-02  3000   5000     2500       5000    15500    3875.0
# 2019-05-03  5000   6000     3000       3000    17000    4250.0
# 2019-05-04  7000   5500     4000       5000    21500    5375.0
# 2019-05-05  5500   4500     3000       4000    17000    4250.0

# %%
team_df.loc[(team_df.index >= '2019-05-03') & (team_df["row_sum"] >= 15000)]
# Out:
#             toto  apple  gildong  catanddog  row_sum  row_mean
# 2019-05-03  5000   6000     3000       3000    17000    4250.0
# 2019-05-04  7000   5500     4000       5000    21500    5375.0
# 2019-05-05  5500   4500     3000       4000    17000    4250.0

# %%
team_df.loc[team_df.row_sum >= 15000,:].loc['2019-05-03':'2019-05-05',:]
# Out:
#             toto  apple  gildong  catanddog  row_sum  row_mean
# 2019-05-03  5000   6000     3000       3000    17000    4250.0
# 2019-05-04  7000   5500     4000       5000    21500    5375.0
# 2019-05-05  5500   4500     3000       4000    17000    4250.0

# %% [markdown]
# ### Titanic 데이터 실습

# %%
data = sns.load_dataset("titanic")
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
sns.histplot(data.fare)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.boxplot(data.fare)
# Out:
# /Users/seungwoomun/opt/anaconda3/envs/likelion/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fare'>

# %%
data.fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %% [markdown]
# ### 그룹화
# * 1번 그룹 : 0 ~ 7.9104
# * 2번 그룹 : 7.9104 ~ 14.4542
# * 3번 그룹 : 14.4542 ~ 31
# * 4번 그룹 : 31 ~ 512

# %%
data_fare01 = data.loc[(data.fare >= 0) & (data.fare <= 7.9104), :]
data_fare02 = data.loc[(data.fare > 7.9104) & (data.fare <= 14.4542), :]
data_fare03 = data.loc[(data.fare > 14.4542) & (data.fare <= 31), :]
data_fare04 = data.loc[(data["fare"] > 31) & (data.fare <= 513), :]

# %%
print(data_fare01.shape)
print(data_fare02.shape)
print(data_fare03.shape)
print(data_fare04.shape)
# Out:
# (223, 17)
# (224, 17)
# (222, 17)
# (222, 17)

# %%
data_fare04.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 13         0       3    male  39.0      1      5  31.2750        S  Third
# 23         1       1    male  28.0      0      0  35.5000        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 13    man        True  NaN  Southampton    no  False
# 23    man        True    A  Southampton   yes   True

# %%
sns.histplot(data_fare01.fare)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data_fare02.fare)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data_fare03.fare)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data_fare04.fare)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %% [markdown]
# ### group fare column 추가

# %%
data.loc[(data.fare >= 0) & (data.fare <= 7.9104), "group_fare"] = 1
data.loc[(data.fare > 7.9104) & (data.fare <= 14.4542), "group_fare"] = 2
data.loc[(data.fare > 14.4542) & (data.fare <= 31), "group_fare"] = 3
data.loc[(data["fare"] > 31) & (data.fare <= 513), "group_fare"] = 4

grp_fare01 = data[data["group_fare"] == 1]
grp_fare02 = data[data["group_fare"] == 2]
grp_fare03 = data[data["group_fare"] == 3]
grp_fare04 = data[data["group_fare"] == 4]

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  group_fare
# 0    man        True  NaN  Southampton    no  False         1.0
# 1  woman       False    C    Cherbourg   yes  False         4.0
# 2  woman       False  NaN  Southampton   yes   True         2.0
# 3  woman       False    C  Southampton   yes  False         4.0
# 4    man        True  NaN  Southampton    no   True         2.0

# %%
plt.figure(figsize = (15, 15))
plt.subplot(2, 2, 1)
sns.histplot(x = "fare", data = grp_fare01)

plt.subplot(2, 2, 2)
sns.histplot(x = "fare", data = grp_fare02)

plt.subplot(2, 2, 3)
sns.histplot(x = "fare", data = grp_fare03)

plt.subplot(2, 2, 4)
sns.histplot(x = "fare", data = grp_fare04)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %% [markdown]
# ### age 그룹 나누기

# %%
data.age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
data.loc[(data.age >= 0) & (data.age < 10), "group_age"] = 0
data.loc[(data.age >= 10) & (data.age < 20), "group_age"] = 10
data.loc[(data.age >= 20) & (data.age <30), "group_age"] = 20
data.loc[(data.age >= 30) & (data.age <40), "group_age"] = 30
data.loc[(data.age >= 40) & (data.age <50), "group_age"] = 40
data.loc[(data.age >= 50) & (data.age <60), "group_age"] = 50
data.loc[(data.age >= 60) & (data.age <70), "group_age"] = 60
data.loc[(data.age >= 70) & (data.age <80), "group_age"] = 70
data.loc[(data.age >= 80) & (data.age <90), "group_age"] = 80

grp_age01 = data[data["group_age"] == 0]
grp_age02 = data[data["group_age"] == 10]
grp_age03 = data[data["group_age"] == 20]
grp_age04 = data[data["group_age"] == 30]
grp_age05 = data[data["group_age"] == 40]
grp_age06 = data[data["group_age"] == 50]
grp_age07 = data[data["group_age"] == 60]
grp_age08 = data[data["group_age"] == 70]
grp_age09 = data[data["group_age"] == 80]

# %%
plt.figure(figsize = (15, 15))

plt.subplot(5, 2, 1)
sns.histplot(x = "age", data = grp_age01)
plt.title("age group 1 histogram")

plt.subplot(5, 2, 2)
sns.histplot(x = "age", data = grp_age02)
plt.title("age group 2 histogram")

plt.subplot(5, 2, 3)
sns.histplot(x = "age", data = grp_age03)
plt.title("age group 3 histogram")

plt.subplot(5, 2, 4)
sns.histplot(x = "age", data = grp_age04)
plt.title("age group 4 histogram")

plt.subplot(5, 2, 5)
sns.histplot(x = "age", data = grp_age05)
plt.title("age group 5 histogram")

plt.subplot(5, 2, 6)
sns.histplot(x = "age", data = grp_age06)
plt.title("age group 6 histogram")

plt.subplot(5, 2, 7)
sns.histplot(x = "age", data = grp_age07)
plt.title("age group 7 histogram")

plt.subplot(5, 2, 8)
sns.histplot(x = "age", data = grp_age08)
plt.title("age group 8 histogram")

plt.subplot(5, 2, 9)
sns.histplot(x = "age", data = grp_age09)
plt.title("age group 9 histogram")
# Out:
# Text(0.5, 1.0, 'age group 9 histogram')

# %% [markdown]
# ### Group별 통계

# %%
data.groupby(['group_fare']).mean()
# Out:
#             survived    pclass        age     sibsp     parch       fare  \
# group_fare
# 1.0         0.197309  2.919283  28.328671  0.053812  0.022422   7.034172
# 2.0         0.303571  2.616071  28.989600  0.147321  0.098214  10.386050
# 3.0         0.454955  2.225225  29.086610  0.752252  0.612613  23.028677
# 4.0         0.581081  1.468468  31.999588  1.144144  0.797297  88.677872
#
#             adult_male     alone  group_age
# group_fare
# 1.0           0.802691  0.941704  23.846154
# 2.0           0.683036  0.834821  24.700000
# 3.0           0.500000  0.342342  24.576271
# 4.0           0.423423  0.288288  27.474227

# %%
data.groupby(['group_fare']).sum()
# Out:
#             survived  pclass      age  sibsp  parch        fare  adult_male  \
# group_fare
# 1.0               44     651  4051.00     12      5   1568.6203         179
# 2.0               68     586  5797.92     33     22   2326.4752         153
# 3.0              101     494  5148.33    167    136   5112.3662         111
# 4.0              129     326  6207.92    254    177  19686.4876          94
#
#             alone  group_age
# group_fare
# 1.0           210     3410.0
# 2.0           187     4940.0
# 3.0            76     4350.0
# 4.0            64     5330.0

# %%
data.groupby(["group_fare"]).median()
# Out:
#             survived  pclass   age  sibsp  parch      fare  adult_male  alone  \
# group_fare
# 1.0              0.0     3.0  25.0    0.0    0.0   7.75000         1.0    1.0
# 2.0              0.0     3.0  28.0    0.0    0.0   9.84375         1.0    1.0
# 3.0              0.0     2.0  30.0    1.0    0.0  25.46670         0.5    0.0
# 4.0              1.0     1.0  31.5    1.0    0.0  69.55000         0.0    0.0
#
#             group_age
# group_fare
# 1.0              20.0
# 2.0              20.0
# 3.0              30.0
# 4.0              30.0

# %%
data.groupby(["group_fare"]).count()
# Out:
#             survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# group_fare
# 1.0              223     223  223  143    223    223   223       223    223
# 2.0              224     224  224  200    224    224   224       224    224
# 3.0              222     222  222  177    222    222   222       222    222
# 4.0              222     222  222  194    222    222   222       220    222
#
#             who  adult_male  deck  embark_town  alive  alone  group_age
# group_fare
# 1.0         223         223     8          223    223    223        143
# 2.0         224         224    16          224    224    224        200
# 3.0         222         222    41          222    222    222        177
# 4.0         222         222   138          220    222    222        194

# %%
sel = ['pclass', 'sex', 'age', 'fare', 'group_fare']
data[sel].groupby(['group_fare']).count()
# Out:
#             pclass  sex  age  fare
# group_fare
# 1.0            223  223  143   223
# 2.0            224  224  200   224
# 3.0            222  222  177   222
# 4.0            222  222  194   222

# %%
# 성별, pclass별 count 수
data.groupby(["sex", "pclass"]).count()
# Out:
#                survived  age  sibsp  parch  fare  embarked  class  who  \
# sex    pclass
# female 1             94   85     94     94    94        92     94   94
#        2             76   74     76     76    76        76     76   76
#        3            144  102    144    144   144       144    144  144
# male   1            122  101    122    122   122       122    122  122
#        2            108   99    108    108   108       108    108  108
#        3            347  253    347    347   347       347    347  347
#
#                adult_male  deck  embark_town  alive  alone  group_fare  \
# sex    pclass
# female 1               94    81           92     94     94          94
#        2               76    10           76     76     76          76
#        3              144     6          144    144    144         144
# male   1              122    94          122    122    122         122
#        2              108     6          108    108    108         108
#        3              347     6          347    347    347         347
#
#                group_age
# sex    pclass
# female 1              85
#        2              74
#        3             102
# male   1             101
#        2              99
#        3             253

# %%
data.groupby(["sex", "pclass", 'embarked']).count()
# Out:
#                         survived  age  sibsp  parch  fare  class  who  \
# sex    pclass embarked
# female 1      C               43   38     43     43    43     43   43
#               Q                1    1      1      1     1      1    1
#               S               48   44     48     48    48     48   48
#        2      C                7    7      7      7     7      7    7
#               Q                2    1      2      2     2      2    2
#               S               67   66     67     67    67     67   67
#        3      C               23   16     23     23    23     23   23
#               Q               33   10     33     33    33     33   33
#               S               88   76     88     88    88     88   88
# male   1      C               42   36     42     42    42     42   42
#               Q                1    1      1      1     1      1    1
#               S               79   64     79     79    79     79   79
#        2      C               10    8     10     10    10     10   10
#               Q                1    1      1      1     1      1    1
#               S               97   90     97     97    97     97   97
#        3      C               43   25     43     43    43     43   43
#               Q               39   14     39     39    39     39   39
#               S              265  214    265    265   265    265  265
#
#                         adult_male  deck  embark_town  alive  alone  \
# sex    pclass embarked
# female 1      C                 43    35           43     43     43
#               Q                  1     1            1      1      1
#               S                 48    43           48     48     48
#        2      C                  7     1            7      7      7
#               Q                  2     1            2      2      2
#               S                 67     8           67     67     67
#        3      C                 23     1           23     23     23
#               Q                 33     0           33     33     33
#               S                 88     5           88     88     88
# male   1      C                 42    31           42     42     42
#               Q                  1     1            1      1      1
#               S                 79    62           79     79     79
#        2      C                 10     1           10     10     10
#               Q                  1     0            1      1      1
#               S                 97     5           97     97     97
#        3      C                 43     0           43     43     43
#               Q                 39     1           39     39     39
#               S                265     5          265    265    265
#
#                         group_fare  group_age
# sex    pclass embarked
# female 1      C                 43         38
#               Q                  1          1
#               S                 48         44
#        2      C                  7          7
#               Q                  2          1
#               S                 67         66
#        3      C                 23         16
#               Q                 33         10
#               S                 88         76
# male   1      C                 42         36
#               Q                  1          1
#               S                 79         64
#        2      C                 10          8
#               Q                  1          1
#               S                 97         90
#        3      C                 43         25
#               Q                 39         14
#               S                265        214

# %%
data.groupby(["sex", "pclass", 'embarked', 'group_age']).count()
# Out:
#                                   survived  age  sibsp  parch  fare  class  \
# sex    pclass embarked group_age
# female 1      C        10.0              5    5      5      5     5      5
#                        20.0              7    7      7      7     7      7
#                        30.0             11   11     11     11    11     11
#                        40.0              7    7      7      7     7      7
#                        50.0              7    7      7      7     7      7
# ...                                    ...  ...    ...    ...   ...    ...
# male   3      S        30.0             45   45     45     45    45     45
#                        40.0             21   21     21     21    21     21
#                        50.0              6    6      6      6     6      6
#                        60.0              1    1      1      1     1      1
#                        70.0              1    1      1      1     1      1
#
#                                   who  adult_male  deck  embark_town  alive  \
# sex    pclass embarked group_age
# female 1      C        10.0         5           5     5            5      5
#                        20.0         7           7     7            7      7
#                        30.0        11          11     8           11     11
#                        40.0         7           7     6            7      7
#                        50.0         7           7     6            7      7
# ...                               ...         ...   ...          ...    ...
# male   3      S        30.0        45          45     1           45     45
#                        40.0        21          21     1           21     21
#                        50.0         6           6     0            6      6
#                        60.0         1           1     0            1      1
#                        70.0         1           1     0            1      1
#
#                                   alone  group_fare
# sex    pclass embarked group_age
# female 1      C        10.0           5           5
#                        20.0           7           7
#                        30.0          11          11
#                        40.0           7           7
#                        50.0           7           7
# ...                                 ...         ...
# male   3      S        30.0          45          45
#                        40.0          21          21
#                        50.0           6           6
#                        60.0           1           1
#                        70.0           1           1
#
# [86 rows x 13 columns]
