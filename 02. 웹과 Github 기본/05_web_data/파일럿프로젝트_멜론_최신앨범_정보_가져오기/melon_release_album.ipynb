# %%
# 멜론 홈페이지의 최신 앨범 정보 크롤링
# 최신앨범(국내, 해외)의 앨범명, 아티스트, 좋아요수, 수록곡수, 발매일 크롤링
# DataFrame 생성 후, CSV 파일로 저장
# CSV 파일명 : 크롤링한 날짜_최신앨범정보.csv

# %%
from selenium import webdriver
import pandas as pd
import time
from datetime import datetime

# %%
melon_url = "https://www.melon.com/index.htm"
driver = webdriver.Chrome("../DATA/chromedriver")
driver.get(melon_url)

# %%
# 최신음악 메뉴
# 최신음악 버튼 xpath : //*[@id="gnb_menu"]/ul[1]/li[2]/a
new_song_button = driver.find_element_by_xpath('//*[@id="gnb_menu"]/ul[1]/li[2]/a')
new_song_button.click()

time.sleep(1)

# 최신앨범 탭
# 최신앨범 버튼 xpath : //*[@id="gnb_menu"]/ul[1]/li[2]/div/ul/li[2]/a
new_album_button = driver.find_element_by_xpath('//*[@id="gnb_menu"]/ul[1]/li[2]/div/ul/li[2]/a')
new_album_button.click()

# %%
# 최신앨범 앨범명, 아티스트, 좋아요수, 수록곡수, 발매일 가져오기

# 변수명
# new album title list : nat_list
# new album artist list : naa_list
# new album heart cnt list : nahc_list
# new album song cnt list : nasc_list
# new album release date list : nard_list

# 앨범제목 xpath : //*[@id="frm"]/div/ul/li[1]/div[2]/div[1]/a
#                //*[@id="frm"]/div/ul/li[3]/div[2]/div[1]/a
#                //*[@id="frm"]/div/ul/li[20]/div[2]/div[1]/a

# 앨범아티스트 xpath : //*[@id="frm"]/div/ul/li[1]/div[2]/div[1]/span[2]
#                   //*[@id="frm"]/div/ul/li[3]/div[2]/div[1]/span[2]/a
#                   //*[@id="frm"]/div/ul/li[20]/div[2]/div[1]/span[2]/a

# 앨범좋아요수 xpath : //*[@id="frm"]/div/ul/li[1]/div[2]/div[2]/button/span[2]
#                   //*[@id="frm"]/div/ul/li[20]/div[2]/div[2]/button/span[2]

# 수록곡수 xpath : //*[@id="frm"]/div/ul/li[1]/div[2]/div[2]/span[2]
#                //*[@id="frm"]/div/ul/li[3]/div[2]/div[2]/span[2]
#                //*[@id="frm"]/div/ul/li[20]/div[2]/div[2]/span[2]

# 발매일 xpath : //*[@id="frm"]/div/ul/li[1]/div[2]/div[2]/span[1]
#              //*[@id="frm"]/div/ul/li[20]/div[2]/div[2]/span[1]

# page : 1 ~ 9(2page ~ 10page)
# page_num2 : //*[@id="pageObjNavgation"]/div/span/a[1]
# page_num3 : //*[@id="pageObjNavgation"]/div/span/a[2]
# page_num4 : //*[@id="pageObjNavgation"]/div/span/a[3]
# page_num10 : //*[@id="pageObjNavgation"]/div/span/a[9]

# next_button xpath : //*[@id="pageObjNavgation"]/div/a
#                     //*[@id="pageObjNavgation"]/div/a[2]

# 해외 button xpath : //*[@id="conts"]/div[2]/ul/li[2]/a

page_cnt = 1
nat_list = []
naa_list = []
nahc_list = []
nasc_list = []
nard_list = []
country_list = []

while True :
    for page in range(1, 11, 1) :
        for num in range(1, 21, 1) :
            album_title = driver.find_elements_by_xpath(f'//*[@id="frm"]/div/ul/li[{num}]/div[2]/div[1]/a')
            for title in album_title :
                nat_list.append(title.text)
            album_artist = driver.find_elements_by_xpath(f'//*[@id="frm"]/div/ul/li[{num}]/div[2]/div[1]/span[2]')
            for artist in album_artist :
                naa_list.append(artist.text)
            album_heart = driver.find_elements_by_xpath(f'//*[@id="frm"]/div/ul/li[{num}]/div[2]/div[2]/button/span[2]')
            for heart in album_heart :
                if "," in heart.text :
                    nahc_list.append(int(heart.text.replace(",", "")))
                else :
                    nahc_list.append(int(heart.text))
            song_cnt = driver.find_elements_by_xpath(f'//*[@id="frm"]/div/ul/li[{num}]/div[2]/div[2]/span[2]')
            for song_num in song_cnt :
                nasc_list.append(song_num.text)
            release_date = driver.find_elements_by_xpath(f'//*[@id="frm"]/div/ul/li[{num}]/div[2]/div[2]/span[1]')
            for date in release_date :
                nard_list.append(date.text)
                country_list.append("국내")
            
                
        try :
            page_button = driver.find_element_by_xpath(f'//*[@id="pageObjNavgation"]/div/span/a[{page}]')
            page_button.click()
            time.sleep(2)
        except :
            break
        finally :
            print(f"{page_cnt}page까지 완료")
        page_cnt += 1

    if page_cnt == 10 :
        next_button = driver.find_element_by_xpath('//*[@id="pageObjNavgation"]/div/a')
        next_button.click()
        time.sleep(2)
    elif page_cnt == 20 :
        next_button = driver.find_element_by_xpath('//*[@id="pageObjNavgation"]/div/a[2]')
        next_button.click()
        time.sleep(2)
    else :
        break
    page_cnt += 1

print("new album title list length :", len(nat_list))
print("new album artist list length :", len(naa_list))
print("new album heart cnt list length :", len(nahc_list))
print("new album song cnt list length :", len(nasc_list))
print("new album release date list length :", len(nard_list))
print("country list length :", len(country_list))
# Out:
# 1page까지 완료
# 2page까지 완료
# 3page까지 완료
# 4page까지 완료
# 5page까지 완료
# 6page까지 완료
# 7page까지 완료
# 8page까지 완료
# 9page까지 완료
# 10page까지 완료
# 11page까지 완료
# 12page까지 완료
# 13page까지 완료
# 14page까지 완료
# 15page까지 완료
# 16page까지 완료
# 17page까지 완료
# 18page까지 완료
# 19page까지 완료
# 20page까지 완료
# 21page까지 완료
# 22page까지 완료
# 23page까지 완료
# 24page까지 완료
# 25page까지 완료
# new album title list length : 500
# new album artist list length : 500
# new album heart cnt list length : 500
# new album song cnt list length : 500
# new album release date list length : 500
# country list length : 500

# %%
# 해외 button xpath : //*[@id="conts"]/div[2]/ul/li[2]/a
foreign_button = driver.find_element_by_xpath('//*[@id="conts"]/div[2]/ul/li[2]/a')
foreign_button.click()
time.sleep(1)

# %%
page_cnt = 1 # page 번호 초기화

while True :
    for page in range(1, 11, 1) :
        for num in range(1, 21, 1) :
            album_title = driver.find_elements_by_xpath(f'//*[@id="frm"]/div/ul/li[{num}]/div[2]/div[1]/a')
            for title in album_title :
                nat_list.append(title.text)
            album_artist = driver.find_elements_by_xpath(f'//*[@id="frm"]/div/ul/li[{num}]/div[2]/div[1]/span[2]')
            for artist in album_artist :
                naa_list.append(artist.text)
            album_heart = driver.find_elements_by_xpath(f'//*[@id="frm"]/div/ul/li[{num}]/div[2]/div[2]/button/span[2]')
            for heart in album_heart :
                if "," in heart.text :
                    nahc_list.append(int(heart.text.replace(",", "")))
                else :
                    nahc_list.append(int(heart.text))
            song_cnt = driver.find_elements_by_xpath(f'//*[@id="frm"]/div/ul/li[{num}]/div[2]/div[2]/span[2]')
            for song_num in song_cnt :
                nasc_list.append(song_num.text)
            release_date = driver.find_elements_by_xpath(f'//*[@id="frm"]/div/ul/li[{num}]/div[2]/div[2]/span[1]')
            for date in release_date :
                nard_list.append(date.text)
                country_list.append("해외")
            
                
        try :
            page_button = driver.find_element_by_xpath(f'//*[@id="pageObjNavgation"]/div/span/a[{page}]')
            page_button.click()
            time.sleep(2)
        except :
            break
        finally :
            print(f"{page_cnt}page까지 완료")
        page_cnt += 1

    if page_cnt == 10 :
        next_button = driver.find_element_by_xpath('//*[@id="pageObjNavgation"]/div/a')
        next_button.click()
        time.sleep(2)
    elif page_cnt == 20 :
        next_button = driver.find_element_by_xpath('//*[@id="pageObjNavgation"]/div/a[2]')
        next_button.click()
        time.sleep(2)
    else :
        break
    page_cnt += 1

print("new album title list length :", len(nat_list))
print("new album artist list length :", len(naa_list))
print("new album heart cnt list length :", len(nahc_list))
print("new album song cnt list length :", len(nasc_list))
print("new album release date list length :", len(nard_list))
print("country list length :", len(country_list))
# Out:
# 1page까지 완료
# 2page까지 완료
# 3page까지 완료
# 4page까지 완료
# 5page까지 완료
# 6page까지 완료
# 7page까지 완료
# 8page까지 완료
# 9page까지 완료
# 10page까지 완료
# 11page까지 완료
# 12page까지 완료
# 13page까지 완료
# 14page까지 완료
# 15page까지 완료
# 16page까지 완료
# 17page까지 완료
# 18page까지 완료
# 19page까지 완료
# 20page까지 완료
# 21page까지 완료
# 22page까지 완료
# 23page까지 완료
# 24page까지 완료
# 25page까지 완료
# new album title list length : 1000
# new album artist list length : 1000
# new album heart cnt list length : 1000
# new album song cnt list length : 1000
# new album release date list length : 1000
# country list length : 1000

# %%
for idx, val in enumerate(nasc_list) :
    print(idx + 1, val)
# Out:
# 1 2곡
# 2 2곡
# 3 1곡
# 4 5곡
# 5 5곡
# 6 1곡
# 7 1곡
# 8 1곡
# 9 1곡
# 10 4곡
# 11 1곡
# 12 1곡
# 13 1곡
# 14 2곡
# 15 23곡
# 16 2곡
# 17 6곡
# 18 1곡
# 19 1곡
# 20 2곡
# 21 2곡
# 22 1곡
# 23 5곡
# 24 10곡
# 25 1곡
# 26 6곡
# 27 2곡
# 28 1곡
# 29 2곡
# 30 1곡
# 31 2곡
# 32 1곡
# 33 13곡
# 34 1곡
# 35 1곡
# 36 1곡
# 37 1곡
# 38 1곡
# 39 2곡
# 40 2곡
# 41 7곡
# 42 2곡
# 43 1곡
# 44 1곡
# 45 2곡
# 46 5곡
# 47 1곡
# 48 2곡
# 49 11곡
# 50 3곡
# 51 2곡
# 52 1곡
# 53 1곡
# 54 1곡
# 55 2곡
# 56 3곡
# 57 2곡
# 58 1곡
# 59 2곡
# 60 3곡
# 61 12곡
# 62 1곡
# 63 1곡
# 64 1곡
# 65 2곡
# 66 1곡
# 67 1곡
# 68 1곡
# 69 1곡
# 70 6곡
# 71 2곡
# 72 1곡
# 73 2곡
# 74 2곡
# 75 4곡
# 76 1곡
# 77 2곡
# 78 2곡
# 79 2곡
# 80 1곡
# 81 1곡
# 82 2곡
# 83 2곡
# 84 1곡
# 85 1곡
# 86 1곡
# 87 1곡
# 88 2곡
# 89 2곡
# 90 2곡
# 91 2곡
# 92 1곡
# 93 1곡
# 94 1곡
# 95 1곡
# 96 1곡
# 97 1곡
# 98 1곡
# 99 2곡
# 100 1곡
# 101 2곡
# 102 1곡
# 103 2곡
# 104 2곡
# 105 1곡
# 106 2곡
# 107 2곡
# 108 3곡
# 109 1곡
# 110 2곡
# 111 6곡
# 112 12곡
# 113 2곡
# 114 1곡
# 115 1곡
# 116 3곡
# 117 2곡
# 118 1곡
# 857 1곡
# 858 4곡
# 859 1곡
# 860 1곡
# 861 1곡
# 862 1곡
# 863 11곡
# 864 1곡
# 865 9곡
# 866 3곡
# 867 1곡
# 868 1곡
# 869 2곡
# 870 6곡
# 871 1곡
# 872 1곡
# 873 1곡
# 874 1곡
# 875 1곡
# 876 1곡
# 877 1곡
# 878 1곡
# 879 15곡
# 880 1곡
# 881 1곡
# 882 1곡
# 883 1곡
# 884 3곡
# 885 10곡
# 886 1곡
# 887 1곡
# 888 1곡
# 889 1곡
# 890 1곡
# 891 10곡
# 892 1곡
# 893 1곡
# 894 1곡
# 895 6곡
# 896 1곡
# 897 3곡
# 898 7곡
# 899 2곡
# 900 1곡
# 901 1곡
# 902 1곡
# 903 1곡
# 904 10곡
# 905 1곡
# 906 1곡
# 907 10곡
# 908 1곡
# 909 7곡
# 910 1곡
# 911 1곡
# 912 5곡
# 913 1곡
# 914 6곡
# 915 2곡
# 916 1곡
# 917 1곡
# 918 1곡
# 919 1곡
# 920 1곡
# 921 1곡
# 922 1곡
# 923 16곡
# 924 1곡
# 925 1곡
# 926 1곡
# 927 2곡
# 928 4곡
# 929 1곡
# 930 1곡
# 931 1곡
# 932 1곡
# 933 1곡
# 934 6곡
# 935 1곡
# 936 1곡
# 937 1곡
# 938 5곡
# 939 5곡
# 940 1곡
# 941 16곡
# 942 1곡
# 943 1곡
# 944 1곡
# 945 2곡
# 946 1곡
# 947 12곡
# 948 35곡
# 949 1곡
# 950 1곡
# 951 5곡
# 952 1곡
# 953 1곡
# 954 1곡
# 955 1곡
# 956 1곡
# 957 1곡
# 958 1곡
# 959 1곡
# 960 1곡
# 961 16곡
# 962 3곡
# 963 1곡
# 964 10곡
# 965 1곡
# 966 1곡
# 967 1곡
# 968 1곡
# 969 1곡
# 970 1곡
# 971 1곡
# 972 11곡
# 973 1곡
# 974 2곡
# 975 1곡
# 976 1곡
# 977 7곡
# 978 1곡
# 979 1곡
# 980 1곡
# 981 1곡
# 982 1곡
# 983 1곡
# 984 1곡
# 985 1곡
# 986 1곡
# 987 1곡
# 988 1곡
# 989 2곡
# 990 1곡
# 991 2곡
# 992 1곡
# 993 1곡
# 994 1곡
# 995 2곡
# 996 12곡
# 997 1곡
# 998 12곡
# 999 1곡
# 1000 5곡

# %%
# 앨범 정보 DataFrame 생성
album_dict = {"곡 제목" : nat_list, "아티스트" : naa_list, "좋아요" : nahc_list, "수록곡 수" : nasc_list, "발매일" : nard_list, "국가" : country_list}
album_df = pd.DataFrame(album_dict)
print(album_df)
album_df.to_csv("./" + datetime.today().strftime("%Y_%m_%d") + "_최신앨범정보.csv", index = False)
# Out:
#                                       곡 제목                    아티스트   좋아요  \
# 0                                   그때의 우리     먼데이 키즈 (Monday Kiz)   355
# 1                            싸이월드 BGM 2021       데이브레이크 (DAYBREAK)   130
# 2                                      레몬밤             셀린 (Celine)    48
# 3                            Somebody Else            참솜 (Chamsom)    72
# 4                               MILLENNIUM            Bronze (브론즈)    49
# ..                                     ...                     ...   ...
# 995                               Baby Boy               Jay Lonzo     5
# 996  2 Phút Hơn (Make It Hot) [KAIZ Remix]              Phao, Tyga    30
# 997                   Music Of The Spheres                Coldplay  1654
# 998                          INDUSTRY BABY  Lil Nas X, Jack Harlow   562
# 999                         Moral Panic II     Nothing But Thieves   178
#
#     수록곡 수         발매일  국가
# 0      2곡  2021.09.16  국내
# 1      2곡  2021.09.16  국내
# 2      1곡  2021.09.16  국내
# 3      5곡  2021.09.16  국내
# 4      5곡  2021.09.16  국내
# ..    ...         ...  ..
# 995   12곡  2021.07.28  해외
# 996    1곡  2021.07.23  해외
# 997   12곡  2021.07.23  해외
# 998    1곡  2021.07.23  해외
# 999    5곡  2021.07.23  해외
#
# [1000 rows x 6 columns]

# %%
album_df.sort_values("좋아요", ascending = False)
# Out:
#                                     곡 제목               아티스트    좋아요 수록곡 수  \
# 132                                   선물   백예린 (Yerin Baek)  19306    6곡
# 414                       홍천기 OST Part.1      백현 (BAEKHYUN)  13278    2곡
# 424                         4U : OUTSIDE                비투비  11537    6곡
# 149                               LALISA          리사 (LISA)   9529    2곡
# 247                           STEREOTYPE        STAYC(스테이씨)   8821    4곡
# ..                                   ...                ...    ...   ...
# 561                              My Love  Addy Ace, Vic Roz      0    1곡
# 939          Adventures of Tricky N Duke         Miso Extra      0    1곡
# 868                     Ain't goin' home   Jeffrey Bergmann      0    2곡
# 613  Skyscrapers (Remixes) (Edited Ver.)        Nina Kraviz      0    9곡
# 521                      Sangre Poderosa           Andrekza      0    1곡
#
#             발매일  국가
# 132  2021.09.10  국내
# 414  2021.08.31  국내
# 424  2021.08.30  국내
# 149  2021.09.10  국내
# 247  2021.09.06  국내
# ..          ...  ..
# 561  2021.09.13  해외
# 939  2021.08.03  해외
# 868  2021.08.11  해외
# 613  2021.09.03  해외
# 521  2021.09.16  해외
#
# [1000 rows x 6 columns]

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   곡 제목    1000 non-null   object
#  1   아티스트    1000 non-null   object
#  2   좋아요     1000 non-null   int64
#  3   수록곡 수   1000 non-null   object
#  4   발매일     1000 non-null   object
#  5   국가      1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 상위 25% 확인

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   곡 제목    1000 non-null   object
#  1   아티스트    1000 non-null   object
#  2   좋아요     1000 non-null   int64
#  3   수록곡 수   1000 non-null   object
#  4   발매일     1000 non-null   object
#  5   국가      1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
heart_high = album_df.loc[album_df["좋아요"] >=79, :].sort_values("좋아요", ascending = False)
heart_high
# Out:
#                                                곡 제목  \
# 132                                              선물
# 414                                  홍천기 OST Part.1
# 424                                    4U : OUTSIDE
# 149                                          LALISA
# 247                                      STEREOTYPE
# ..                                              ...
# 681                                             999
# 880  Love Runs Out (Feat. G-Eazy, Sasha Alex Sloan)
# 472                                       Day&Night
# 591                               Pacifico (Deluxe)
# 272                                    Call My Name
#
#                            아티스트    좋아요 수록곡 수         발매일  국가
# 132            백예린 (Yerin Baek)  19306    6곡  2021.09.10  국내
# 414               백현 (BAEKHYUN)  13278    2곡  2021.08.31  국내
# 424                         비투비  11537    6곡  2021.08.30  국내
# 149                   리사 (LISA)   9529    2곡  2021.09.10  국내
# 247                 STAYC(스테이씨)   8821    4곡  2021.09.06  국내
# ..                          ...    ...   ...         ...  ..
# 681        Selena Gomez, Camilo     81    1곡  2021.08.26  해외
# 880               Martin Garrix     80    1곡  2021.08.06  해외
# 472  디 애프터 (The After), Ja Mezz     80    2곡  2021.08.29  국내
# 591                    Surfaces     80   20곡  2021.09.03  해외
# 272           페리블루 (Ferry Blue)     79    1곡  2021.09.06  국내
#
# [251 rows x 6 columns]

# %% [markdown]
# ### 좋아요 상위 20개 데이터 확인

# %%
heart_high.head(20)
# Out:
#                          곡 제목                                    아티스트    좋아요  \
# 132                        선물                        백예린 (Yerin Baek)  19306
# 414            홍천기 OST Part.1                           백현 (BAEKHYUN)  13278
# 424              4U : OUTSIDE                                     비투비  11537
# 149                    LALISA                               리사 (LISA)   9529
# 247                STEREOTYPE                             STAYC(스테이씨)   8821
# 256                   Eternal                          Young K (DAY6)   8740
# 428              Hate that...                                 키 (KEY)   8064
# 158                    4 ONLY                                     이하이   7363
# 420            사랑의 콜센타 PART68                         Various Artists   6827
# 673                     Donda                              Kanye West   6183
# 244            사랑의 콜센타 PART69                         Various Artists   5993
# 14   I SAY MAMAMOO : THE BEST                           마마무 (Mamamoo)   5696
# 551                   One Day                                   몬스타엑스   5438
# 48                       초희귀종                                     한요한   4975
# 60             사랑의 콜센타 PART70                         Various Artists   4424
# 550                   Shivers                              Ed Sheeran   4374
# 944                     Skate  Bruno Mars, Anderson .Paak, Silk Sonic   4356
# 297                      Loop                               I.M (아이엠)   3989
# 342        Moments in between                                넬 (NELL)   3701
# 69        ZERO : FEVER Part.3                            ATEEZ (에이티즈)   3530
#
#     수록곡 수         발매일  국가
# 132    6곡  2021.09.10  국내
# 414    2곡  2021.08.31  국내
# 424    6곡  2021.08.30  국내
# 149    2곡  2021.09.10  국내
# 247    4곡  2021.09.06  국내
# 256    7곡  2021.09.06  국내
# 428    1곡  2021.08.30  국내
# 158   10곡  2021.09.09  국내
# 420   12곡  2021.08.31  국내
# 673   27곡  2021.08.29  해외
# 244   12곡  2021.09.07  국내
# 14    23곡  2021.09.15  국내
# 551    1곡  2021.09.10  해외
# 48    11곡  2021.09.14  국내
# 60    12곡  2021.09.14  국내
# 550    3곡  2021.09.10  해외
# 944    2곡  2021.07.30  해외
# 297    1곡  2021.09.04  국내
# 342   10곡  2021.09.02  국내
# 69     6곡  2021.09.13  국내

# %% [markdown]
# ### 좋아요 1000 이상 앨범 조회
# * 좋아요 내림차순 정렬

# %%
like1000 = album_df.loc[album_df["좋아요"] >= 1000, :]
print("좋아요 1000 이상인 앨범의 개수 :", len(like1000))

like1000.sort_values("좋아요", ascending = False)
# Out:
# 좋아요 1000 이상인 앨범의 개수 : 55
#                                                곡 제목  \
# 132                                              선물
# 414                                  홍천기 OST Part.1
# 424                                    4U : OUTSIDE
# 149                                          LALISA
# 247                                      STEREOTYPE
# 256                                         Eternal
# 428                                    Hate that...
# 158                                          4 ONLY
# 420                                  사랑의 콜센타 PART68
# 673                                           Donda
# 244                                  사랑의 콜센타 PART69
# 14                         I SAY MAMAMOO : THE BEST
# 551                                         One Day
# 48                                             초희귀종
# 60                                   사랑의 콜센타 PART70
# 550                                         Shivers
# 944                                           Skate
# 297                                            Loop
# 342                              Moments in between
# 69                              ZERO : FEVER Part.3
# 477                                            불꽃놀이
# 365                                     Talk & Talk
# 320                                 환승연애 OST Part 2
# 41                           가을 타나 봐 (REVIBE Vol.4)
# 156  0X1=LOVESONG (I Know I Love You) feat. MOD SUN
# 405                                    natural high
# 392                         시간을 거슬러 (낮에 뜨는 달 X 케이윌)
# 343                                           ALIVE
# 157                                           1+1=1
# 362                        별이 빛나는 밤에 (REVIBE Vol.3)
# 775                                     Good Things
# 329                     슬기로운 의사생활 시즌2 OST Special 2
# 480                                         야화첩 OST
# 448                                       세 번째 '고백'
# 274                              갯마을 차차차 OST Part 1
# 494                                        D.P. OST
# 690                        COMING HOME (feat. NIKI)
# 997                            Music Of The Spheres
# 142                                            PADO
# 947                          F*CK LOVE 3+: OVER YOU
# 40                                      Blue Letter
# 248                                  홍천기 OST Part.2
# 319                        MAXIS BY RYAN JHUN PT. 2
# 617                             Certified Lover Boy
# 357                     It's You (예리 of Red Velvet)
# 26                              Trilogy Ⅱ. Speranza
# 940                               Happier Than Ever
# 89                                    끝이라고 말할 것 같았어
# 219                                         Observe
# 547                                      Angel Baby
# 55              iScreaM Vol.10 : Next Level Remixes
# 581                           영화 '샹치와 텐 링즈의 전설' OST
# 429                          남아있어 (경찰수업 OST Part.5)
# 393      Dingo X Dejavu Group 'Wrote This Tomorrow'
# 625                                        gg bb xx
#
#                                                   아티스트    좋아요 수록곡 수  \
# 132                                   백예린 (Yerin Baek)  19306    6곡
# 414                                      백현 (BAEKHYUN)  13278    2곡
# 424                                                비투비  11537    6곡
# 149                                          리사 (LISA)   9529    2곡
# 247                                        STAYC(스테이씨)   8821    4곡
# 256                                     Young K (DAY6)   8740    7곡
# 428                                            키 (KEY)   8064    1곡
# 158                                                이하이   7363   10곡
# 420                                    Various Artists   6827   12곡
# 673                                         Kanye West   6183   27곡
# 244                                    Various Artists   5993   12곡
# 14                                       마마무 (Mamamoo)   5696   23곡
# 551                                              몬스타엑스   5438    1곡
# 48                                                 한요한   4975   11곡
# 60                                     Various Artists   4424   12곡
# 550                                         Ed Sheeran   4374    3곡
# 944             Bruno Mars, Anderson .Paak, Silk Sonic   4356    2곡
# 297                                          I.M (아이엠)   3989    1곡
# 342                                           넬 (NELL)   3701   10곡
# 69                                        ATEEZ (에이티즈)   3530    6곡
# 477                                                하현상   3213    2곡
# 365                                             프로미스나인   2833    1곡
# 320                                                하성운   2677    2곡
# 41                                                 이무진   2572    2곡
# 156                                          투모로우바이투게더   2560    1곡
# 405                                        나플라 (nafla)   2394   13곡
# 392                                                케이윌   2350    2곡
# 343                                       ASTRO (아스트로)   2328    1곡
# 157                                               현아&던   2302    4곡
# 362                                       규현 (KYUHYUN)   2228    2곡
# 775                                         Dan + Shay   2188   12곡
# 329                                            미도와 파라솔   2156    3곡
# 480                                                안예은   1999    2곡
# 448                                               멜로망스   1974    2곡
# 274                                               카더가든   1945    2곡
# 494                                    Various Artists   1850   11곡
# 690                                              HONNE   1709    4곡
# 997                                           Coldplay   1654   12곡
# 142                                          비비 (BIBI)   1584    1곡
# 947                                      The Kid LAROI   1581   35곡
# 40                                          원호 (WONHO)   1545    7곡
# 248                                           솔라 (마마무)   1517    2곡
# 319                                             이달의 소녀   1493    1곡
# 617                                              Drake   1488   21곡
# 357                                          예리 (YERI)   1479    2곡
# 26                                       라포엠 (LA POEM)   1355    2곡
# 940                                      Billie Eilish   1337   16곡
# 89                                                 황치열   1234    2곡
# 219                                                백아연   1157    6곡
# 547                                        Troye Sivan   1155    1곡
# 55                                               aespa   1133    3곡
# 581                           NIKI, DJ Snake, 88rising   1099   18곡
# 429                                          유주 (여자친구)   1098    2곡
# 393  BewhY (비와이), Viann, Khundi Panda, Son Simba (손...   1030    9곡
# 625                                               LANY   1008   12곡
#
#             발매일  국가
# 132  2021.09.10  국내
# 414  2021.08.31  국내
# 424  2021.08.30  국내
# 149  2021.09.10  국내
# 247  2021.09.06  국내
# 256  2021.09.06  국내
# 428  2021.08.30  국내
# 158  2021.09.09  국내
# 420  2021.08.31  국내
# 673  2021.08.29  해외
# 244  2021.09.07  국내
# 14   2021.09.15  국내
# 551  2021.09.10  해외
# 48   2021.09.14  국내
# 60   2021.09.14  국내
# 550  2021.09.10  해외
# 944  2021.07.30  해외
# 297  2021.09.04  국내
# 342  2021.09.02  국내
# 69   2021.09.13  국내
# 477  2021.08.28  국내
# 365  2021.09.01  국내
# 320  2021.09.03  국내
# 41   2021.09.14  국내
# 156  2021.09.10  국내
# 405  2021.08.31  국내
# 392  2021.08.31  국내
# 343  2021.09.02  국내
# 157  2021.09.09  국내
# 362  2021.09.01  국내
# 775  2021.08.13  해외
# 329  2021.09.03  국내
# 480  2021.08.28  국내
# 448  2021.08.29  국내
# 274  2021.09.05  국내
# 494  2021.08.28  국내
# 690  2021.08.27  해외
# 997  2021.07.23  해외
# 142  2021.09.10  국내
# 947  2021.07.27  해외
# 40   2021.09.14  국내
# 248  2021.09.06  국내
# 319  2021.09.03  국내
# 617  2021.09.03  해외
# 357  2021.09.02  국내
# 26   2021.09.15  국내
# 940  2021.07.30  해외
# 89   2021.09.12  국내
# 219  2021.09.07  국내
# 547  2021.09.10  해외
# 55   2021.09.14  국내
# 581  2021.09.03  해외
# 429  2021.08.30  국내
# 393  2021.08.31  국내
# 625  2021.09.03  해외
