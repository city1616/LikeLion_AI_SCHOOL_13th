# %% [markdown]
# ### 2021_09_15_1 2 3

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# np.linspace(시작, 끝, 데이터 개수)
x = np.linspace(0, 14, 100)
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
# np.linspace(시작, 끝, 데이터 개수)
x = np.linspace(0, 14, 100)
y = np.sin(x)
y1 = np.sin(x) * 2
y2 = np.sin(x) * 4

# %%
plt.plot(x, y, x, y1, x, y2)

# %%
plt.plot(x, y, x, y, x, y)

# %%
# 선 그래프가 아닌 점 형태로 출력
plt.plot(x, y, 'o')
plt.plot(x, y1, 'o')
plt.plot(x, y2, 'o')

# %%
plt.plot(x, y, 'o', x, y1, 'o', x, y2, 'o')

# %%
# np.linspace(시작, 끝, 데이터 개수)
# sin, cos, tan
x = np.linspace(0, 14, 100)
y = np.sin(x)
y1 = np.cos(x)
y2 = np.tan(x)

# %%
plt.plot(x, y, x, y1, x, y2)

# %%
# 선 그래프가 아닌 점 형태로 출력
plt.scatter(x, y)

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")

# %%
# np.linspace(시작, 끝, 데이터 개수)
x = np.linspace(0, 14, 100)
y = np.sin(x)
y1 = np.sin(x) * 2
y2 = np.sin(x) * 4

# %%
plt.plot(x, y, x, y1, x, y2)

# %%
tips = sns.load_dataset("tips")
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# * 01 앞뒤의 5개의 행 보기 [].head(), [].tail()
# * 02 데이터 통계량 보기   [].describe()
# * 03 정보 확인하기       [].info()
# * 04 열 확인하기         [].columns
# * 05 행과 열 확인하기     [].shape
# * 06 상위 N행 살펴보기    [].head(N)
# * 07 하위 N행 살펴보기    [].tail(N)
# * 08 통계량 계산         [].mean(), [].max(), [].median()

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.loc

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.head(7)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2

# %% [markdown]
# ### boxplot
# * 명령은 박스-휘스커 플롯(Box-Whisker Plot) 혹은 간단히 박스 플롯이라 부르는 차트를 그려준다.
# * 박스 플롯은 박스와 박스 바깥의 선(whisker)으로 이루어진다.
# * 박스는 실수 값 분포에서 1사분위수(Q1)와 3사분위수(Q3)를 뜻하고 이 3사분위수와 1사분수의 차이(Q3 - Q1)를 IQR(interquartile range)라고 한다.
# * 박스 내부의 가로선은 중앙값을 나타낸다.
# * 박스 외부의 세로선은 1사분위 수보다 1.5 x IQR 만큼 낮은 값과 3사분위 수보다 1.5 x IQR 만큼 높은 값의 구간을 기준으로 그 구간의 내부에 있는 가장 큰 데이터와 가장 작은 데이터를 잇는 선분이다.
# * 그 바깥의 점은 아웃라이어(outlier)라고 부르는데 일일히 점으로 표시한다.

# %% [markdown]
# ### 요일별 식사금액

# %%
sns.boxplot(x = "day", y = "total_bill", data = tips)
plt.show()

# %% [markdown]
# * 식사금액은 토요일과 일요일이 많다.
# * 현재 데이터는 목, 금, 토, 일의 데이터가 있다.
# * 토요일과 일요일을 비교해 본다면 상대적으로 일요일 식사 금액 지출이 많다.

# %% [markdown]
# ### 요일별 팁에 대해 알아보자.

# %%
sns.boxplot(x = "day", y = "tip", data = tips)
plt.show()

# %% [markdown]
# * 목, 금, 토, 일 중 상대적으로 일요일에 tip이 많다.
# * 토요일과 일요일의 식사금액이 많았는데 토, 일 중에서도 일요일에 tip이 많다.
# * 금요일에 중앙값이 높은 편이다.

# %% [markdown]
# ### 요일별 사이즈(식사인원)에 대해 알아보자.

# %%
sns.boxplot(x = "day", y = "size", data = tips)
plt.show()

# %% [markdown]
# * 토, 일에 식사 인원이 많다.
#     * 식사인원이 많기 때문에 식사금액이 상대적으로 높을 수 밖에 없다.
# * 목, 금에 식사 인원은 2명이 대다수이다.
# * 목요일에 이상값이 많다.

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# ### 그러면 누가 팁을 많이 주는 걸까?

# %%
sns.boxplot(x = "day", y = "tip", hue = "sex", data = tips)
plt.show()

# %% [markdown]
# * 남성은 tip을 많이 주는 사람이 있고, 적게 주는 사람도 있다.
# * 토요일은 이상값이 많다.
# * 의문 - 금요일은 일이 끝나서 토요일이 기분이 좋다. 일요일은 다음날 일하러 가야하기 때문에 기분이 안좋다?
# * 의문 - 일요일은 가정이 있다면 남성이 일하러 가기 때문에 여성의 기분이 좋다?

# %% [markdown]
# ### 담배피는 사람, 안피는 사람과 팁의 관계

# %%
sns.boxplot(x = "day", y = "tip", hue = "smoker", data = tips)
plt.show()

# %% [markdown]
# * 목, 금에 흡연자가 tip을 더 많이 준다.
# * 목, 금에 흡연자의 tip 범위가 크다.
# * 흡연 유무를 떠나서 토요일에 이상값이 많다.
# * 일요일에 비흡연자의 편차가 크다.

# %% [markdown]
# ### time과 팁의 관계

# %%
sns.boxplot(x = "day", y = "tip", hue = "time", data = tips)
plt.show()

# %% [markdown]
# * 토, 일에는 저녁에만 tip을 준다.
#     * 주말은 집에서 휴식을 취하는 사람이 많기에 저녁식사 비중이 높다 생각된다.
# * 토요일에는 이상값이 많다.

# %% [markdown]
# ### 식사금액과 팁의 상관관계

# %%
# height -> size
sns.set_style("darkgrid")
sns.lmplot(x = "total_bill", y = "tip", data = tips, height = 7)
plt.show()

# %%
# height -> size
sns.set_style("darkgrid")
sns.lmplot(x = "total_bill", y = "tip", hue = "smoker", data = tips, height = 7)
plt.show()

# %% [markdown]
# ## 항공 데이터 이용

# %%
fg = sns.load_dataset("flights")
print(fg.head(5))
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.scatterplot(x = "year", y = "passengers", data = fg)
plt.show()

# %%
sns.lmplot(x = "year", y = "passengers", data = fg, height = 7)
plt.show()

# %%
sns.lmplot(x = "year", y = "passengers", hue = "month", data = fg, height = 7)
plt.show()

# %%
fgpivot = fg.pivot("month", "year", "passengers")
fgpivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(fgpivot, annot = True)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fgpivot, annot = True, fmt = "d")
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.set(style = 'ticks')
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)
