# %%
import pandas as pd
import numpy as np
import time

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import RandomForestRegressor   # 앙상블(의사결정트리 확장판)
from sklearn.ensemble import GradientBoostingRegressor

# %%
train = pd.read_csv("../CSV/train_data.csv")
test = pd.read_csv("../CSV/pred_test.csv")

print("train shape : {}, test shape : {}".format(train.shape, test.shape))
# Out:
# train shape : (368088, 11), test shape : (15120, 11)

# %%
train.head(3)
# Out:
#           연월일  시간                   일시  year  month  day  hour  weekday 구분  \
# 0  2013-01-01   1  2013-01-01 00:00:00  2013      1    1     0        1  A
# 1  2013-01-01   2  2013-01-01 01:00:00  2013      1    1     1        1  A
# 2  2013-01-01   3  2013-01-01 02:00:00  2013      1    1     2        1  A
#
#         공급량  기온(°C)
# 0  2497.129    -8.3
# 1  2363.265    -8.5
# 2  2258.505    -8.4

# %% [markdown]
# ### LinearRegression

# %%
X = train[["year", "day", "hour", "weekday"]]
y = train["공급량"]

for i in range(1, 10, 1) :
    X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                       test_size = i / 10,
                                                       random_state = 77)

    lr_model = LinearRegression()
    lr_model.fit(X_train, y_train)
    pred = lr_model.predict(X_test)

    # 결정계수 확인
    print("학습용 : {}, 테스트용 : {}".format(10 - i, i))
    print("학습용 데이터 결정계수: {:.3f}".format(lr_model.score(X_train, y_train)))
    print("테스트 데이터 결정계수: {:.3f}".format(lr_model.score(X_test, y_test)))
    print("MSE :", mean_squared_error(y_test, pred))
    print()
    
# model.feature_importances_
# Out:
# 학습용 : 9, 테스트용 : 1
# 학습용 데이터 결정계수: 0.011
# 테스트 데이터 결정계수: 0.012
# MSE : 858995.3820678939
#
# 학습용 : 8, 테스트용 : 2
# 학습용 데이터 결정계수: 0.011
# 테스트 데이터 결정계수: 0.012
# MSE : 851242.2440710817
#
# 학습용 : 7, 테스트용 : 3
# 학습용 데이터 결정계수: 0.012
# 테스트 데이터 결정계수: 0.012
# MSE : 850409.6820350793
#
# 학습용 : 6, 테스트용 : 4
# 학습용 데이터 결정계수: 0.011
# 테스트 데이터 결정계수: 0.012
# MSE : 848899.8309086943
#
# 학습용 : 5, 테스트용 : 5
# 학습용 데이터 결정계수: 0.012
# 테스트 데이터 결정계수: 0.012
# MSE : 845726.3954807592
#
# 학습용 : 4, 테스트용 : 6
# 학습용 데이터 결정계수: 0.011
# 테스트 데이터 결정계수: 0.012
# MSE : 845974.2281729488
#
# 학습용 : 3, 테스트용 : 7
# 학습용 데이터 결정계수: 0.011
# 테스트 데이터 결정계수: 0.012
# MSE : 847413.3274659554
#
# 학습용 : 2, 테스트용 : 8
# 학습용 데이터 결정계수: 0.012
# 테스트 데이터 결정계수: 0.011
# MSE : 849345.726313863
#
# 학습용 : 1, 테스트용 : 9
# 학습용 데이터 결정계수: 0.013
# 테스트 데이터 결정계수: 0.011
# MSE : 849408.0273866793

# %% [markdown]
# ### 다양한 모델 비교
# * LinearRegression
# * DecisionTreeRegressor
# * RandomForestRegressor
# * GradientBoostingRegressor

# %%
start_time = time.time()

X = train[["year", "day", "hour", "weekday"]]
y = train["공급량"]

model_list = ["LinearRegression", 
              "DecisionTreeRegressor", 
              "RandomForestRegressor", 
              "GradientBoostingRegressor"]

models = [LinearRegression(), 
         DecisionTreeRegressor(), 
         RandomForestRegressor(n_jobs = -1, random_state = 37), 
         GradientBoostingRegressor(random_state = 37)]

mse_score = []
model_score = []
 
    
for model in models :
    temp = []
    temp_s = []
    for i in range(1, 10, 1) :
        X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                           test_size = i / 10,
                                                           random_state = 77)
        print("model :", model)
        model.fit(X_train, y_train)
        pred = model.predict(X_test)

        # 결정계수 확인
        print("학습용 : {}, 테스트용 : {}".format(10 - i, i))
        print("학습용 데이터 결정계수: {:.3f}".format(model.score(X_train, y_train)))
        print("테스트 데이터 결정계수: {:.3f}".format(model.score(X_test, y_test)))

        # MSE(Mean Squared Error) 
        print("MSE :", mean_squared_error(y_test, pred))
        print()
        temp.append(mean_squared_error(y_test, pred))
        temp_s.append(model.score(X_test, y_test))
    mse_score.append(temp)
    model_score.append(temp_s)
    
print("실행 시간 : {:.3f}".format(time.time() - start_time))
# Out:
# model : LinearRegression()
# 학습용 : 9, 테스트용 : 1
# 학습용 데이터 결정계수: 0.011
# 테스트 데이터 결정계수: 0.012
# MSE : 858995.3820678939
#
# model : LinearRegression()
# 학습용 : 8, 테스트용 : 2
# 학습용 데이터 결정계수: 0.011
# 테스트 데이터 결정계수: 0.012
# MSE : 851242.2440710817
#
# model : LinearRegression()
# 학습용 : 7, 테스트용 : 3
# 학습용 데이터 결정계수: 0.012
# 테스트 데이터 결정계수: 0.012
# MSE : 850409.6820350793
#
# model : LinearRegression()
# 학습용 : 6, 테스트용 : 4
# 학습용 데이터 결정계수: 0.011
# 테스트 데이터 결정계수: 0.012
# MSE : 848899.8309086943
#
# model : LinearRegression()
# 학습용 : 5, 테스트용 : 5
# 학습용 데이터 결정계수: 0.012
# 테스트 데이터 결정계수: 0.012
# MSE : 845726.3954807592
#
# model : LinearRegression()
# 학습용 : 4, 테스트용 : 6
# 학습용 데이터 결정계수: 0.011
# 테스트 데이터 결정계수: 0.012
# MSE : 845974.2281729488
#
# model : LinearRegression()
# 학습용 : 3, 테스트용 : 7
# 학습용 데이터 결정계수: 0.011
# 테스트 데이터 결정계수: 0.012
# MSE : 847413.3274659554
#
# model : LinearRegression()
# 학습용 : 2, 테스트용 : 8
# 학습용 데이터 결정계수: 0.012
# 테스트 데이터 결정계수: 0.011
# MSE : 849345.726313863
#
# model : LinearRegression()
# 학습용 : 1, 테스트용 : 9
# 학습용 데이터 결정계수: 0.013
# 테스트 데이터 결정계수: 0.011
# MSE : 849408.0273866793
#
# model : DecisionTreeRegressor()
# 학습용 : 9, 테스트용 : 1
# 학습용 데이터 결정계수: 0.199
# 테스트 데이터 결정계수: 0.061
# MSE : 816575.5151588012
#
# model : DecisionTreeRegressor()
# 학습용 : 8, 테스트용 : 2
# 학습용 데이터 결정계수: 0.207
# 테스트 데이터 결정계수: 0.049
# MSE : 819157.7464558868
#
# model : DecisionTreeRegressor()
# 학습용 : 7, 테스트용 : 3
# 학습용 데이터 결정계수: 0.218
# 테스트 데이터 결정계수: 0.036
# MSE : 829773.4777033634
#
# model : DecisionTreeRegressor()
# 학습용 : 6, 테스트용 : 4
# 학습용 데이터 결정계수: 0.232
# 테스트 데이터 결정계수: 0.014
# MSE : 846436.4179266624
#
# model : DecisionTreeRegressor()
# 학습용 : 5, 테스트용 : 5
# 학습용 데이터 결정계수: 0.252
# 테스트 데이터 결정계수: -0.016
# MSE : 869475.4270735643
#
# model : DecisionTreeRegressor()
# 학습용 : 4, 테스트용 : 6
# 학습용 데이터 결정계수: 0.281
# 테스트 데이터 결정계수: -0.062
# MSE : 909288.4856918071
#
# model : DecisionTreeRegressor()
# 학습용 : 3, 테스트용 : 7
# 학습용 데이터 결정계수: 0.330
# 테스트 데이터 결정계수: -0.155
# MSE : 990037.8717668896
#
# model : DecisionTreeRegressor()
# 학습용 : 2, 테스트용 : 8
# 학습용 데이터 결정계수: 0.416
# 테스트 데이터 결정계수: -0.306
# MSE : 1121985.5152750846
#
# model : DecisionTreeRegressor()
# 학습용 : 1, 테스트용 : 9
# 학습용 데이터 결정계수: 0.593
# 테스트 데이터 결정계수: -0.631
# MSE : 1400949.3888838992
#
# model : RandomForestRegressor(n_jobs=-1, random_state=37)
# 학습용 : 9, 테스트용 : 1
# 학습용 데이터 결정계수: 0.198
# 테스트 데이터 결정계수: 0.060
# MSE : 817026.3026619359
#
# model : RandomForestRegressor(n_jobs=-1, random_state=37)
# 학습용 : 8, 테스트용 : 2
# 학습용 데이터 결정계수: 0.206
# 테스트 데이터 결정계수: 0.049
# MSE : 819444.2249508584
#
# model : RandomForestRegressor(n_jobs=-1, random_state=37)
# 학습용 : 7, 테스트용 : 3
# 학습용 데이터 결정계수: 0.217
# 테스트 데이터 결정계수: 0.036
# MSE : 829472.3405244495
#
# model : RandomForestRegressor(n_jobs=-1, random_state=37)
# 학습용 : 6, 테스트용 : 4
# 학습용 데이터 결정계수: 0.231
# 테스트 데이터 결정계수: 0.016
# MSE : 844938.1135160619
#
# model : RandomForestRegressor(n_jobs=-1, random_state=37)
# 학습용 : 5, 테스트용 : 5
# 학습용 데이터 결정계수: 0.251
# 테스트 데이터 결정계수: -0.010
# MSE : 864012.1656653091
#
# model : RandomForestRegressor(n_jobs=-1, random_state=37)
# 학습용 : 4, 테스트용 : 6
# 학습용 데이터 결정계수: 0.278
# 테스트 데이터 결정계수: -0.044
# MSE : 894025.1095768389
#
# model : RandomForestRegressor(n_jobs=-1, random_state=37)
# 학습용 : 3, 테스트용 : 7
# 학습용 데이터 결정계수: 0.324
# 테스트 데이터 결정계수: -0.101
# MSE : 944270.3984435229
#
# model : RandomForestRegressor(n_jobs=-1, random_state=37)
# 학습용 : 2, 테스트용 : 8
# 학습용 데이터 결정계수: 0.399
# 테스트 데이터 결정계수: -0.166
# MSE : 1001481.6633256169
#
# model : RandomForestRegressor(n_jobs=-1, random_state=37)
# 학습용 : 1, 테스트용 : 9
# 학습용 데이터 결정계수: 0.541
# 테스트 데이터 결정계수: -0.234
# MSE : 1059799.7026063986
#
# model : GradientBoostingRegressor(random_state=37)
# 학습용 : 9, 테스트용 : 1
# 학습용 데이터 결정계수: 0.042
# 테스트 데이터 결정계수: 0.044
# MSE : 831334.1042618387
#
# model : GradientBoostingRegressor(random_state=37)
# 학습용 : 8, 테스트용 : 2
# 학습용 데이터 결정계수: 0.042
# 테스트 데이터 결정계수: 0.042
# MSE : 825511.2980920561
#
# model : GradientBoostingRegressor(random_state=37)
# 학습용 : 7, 테스트용 : 3
# 학습용 데이터 결정계수: 0.043
# 테스트 데이터 결정계수: 0.040
# MSE : 825585.6179036476
#
# model : GradientBoostingRegressor(random_state=37)
# 학습용 : 6, 테스트용 : 4
# 학습용 데이터 결정계수: 0.043
# 테스트 데이터 결정계수: 0.041
# MSE : 823813.817876769
#
# model : GradientBoostingRegressor(random_state=37)
# 학습용 : 5, 테스트용 : 5
# 학습용 데이터 결정계수: 0.043
# 테스트 데이터 결정계수: 0.041
# MSE : 820471.0264255633
#
# model : GradientBoostingRegressor(random_state=37)
# 학습용 : 4, 테스트용 : 6
# 학습용 데이터 결정계수: 0.043
# 테스트 데이터 결정계수: 0.041
# MSE : 820913.9695055832
#
# model : GradientBoostingRegressor(random_state=37)
# 학습용 : 3, 테스트용 : 7
# 학습용 데이터 결정계수: 0.044
# 테스트 데이터 결정계수: 0.041
# MSE : 822415.1421751302
#
# model : GradientBoostingRegressor(random_state=37)
# 학습용 : 2, 테스트용 : 8
# 학습용 데이터 결정계수: 0.045
# 테스트 데이터 결정계수: 0.040
# MSE : 824308.6286750595
#
# model : GradientBoostingRegressor(random_state=37)
# 학습용 : 1, 테스트용 : 9
# 학습용 데이터 결정계수: 0.048
# 테스트 데이터 결정계수: 0.040
# MSE : 824988.3264692031
#
# 실행 시간 : 148.538

# %%
print("mse_score length : {}, model_score length : {}".format(len(mse_score), len(model_score)))
print(mse_score)
# Out:
# mse_score length : 4, model_score length : 4
# [[858995.3820678939, 851242.2440710817, 850409.6820350793, 848899.8309086943, 845726.3954807592, 845974.2281729488, 847413.3274659554, 849345.726313863, 849408.0273866793], [816575.5151588012, 819157.7464558868, 829773.4777033634, 846436.4179266624, 869475.4270735643, 909288.4856918071, 990037.8717668896, 1121985.5152750846, 1400949.3888838992], [817026.3026619359, 819444.2249508584, 829472.3405244495, 844938.1135160619, 864012.1656653091, 894025.1095768389, 944270.3984435229, 1001481.6633256169, 1059799.7026063986], [831334.1042618387, 825511.2980920561, 825585.6179036476, 823813.817876769, 820471.0264255633, 820913.9695055832, 822415.1421751302, 824308.6286750595, 824988.3264692031]]

# %%
df = pd.DataFrame({"test_size" : range(1, 10, 1)})
for i in range(0, 4, 1) :
    df[model_list[i] + "_score"] = model_score[i]
for i in range(0, 4, 1) :
    df[model_list[i] + "_MSE"] = mse_score[i]

# %%
df
# Out:
#    test_size  LinearRegression_score  DecisionTreeRegressor_score  \
# 0          1                0.011916                     0.060710
# 1          2                0.011916                     0.049159
# 2          3                0.011561                     0.035546
# 3          4                0.011571                     0.014439
# 4          5                0.011525                    -0.016233
# 5          6                0.011646                    -0.062325
# 6          7                0.011669                    -0.154672
# 7          8                0.011345                    -0.306013
# 8          9                0.011314                    -0.630663
#
#    RandomForestRegressor_score  GradientBoostingRegressor_score  \
# 0                     0.060192                         0.043734
# 1                     0.048826                         0.041784
# 2                     0.035896                         0.040414
# 3                     0.016184                         0.040780
# 4                    -0.009848                         0.041043
# 5                    -0.044492                         0.040924
# 6                    -0.101294                         0.040824
# 7                    -0.165745                         0.040488
# 8                    -0.233575                         0.039738
#
#    LinearRegression_MSE  DecisionTreeRegressor_MSE  RandomForestRegressor_MSE  \
# 0         858995.382068               8.165755e+05               8.170263e+05
# 1         851242.244071               8.191577e+05               8.194442e+05
# 2         850409.682035               8.297735e+05               8.294723e+05
# 3         848899.830909               8.464364e+05               8.449381e+05
# 4         845726.395481               8.694754e+05               8.640122e+05
# 5         845974.228173               9.092885e+05               8.940251e+05
# 6         847413.327466               9.900379e+05               9.442704e+05
# 7         849345.726314               1.121986e+06               1.001482e+06
# 8         849408.027387               1.400949e+06               1.059800e+06
#
#    GradientBoostingRegressor_MSE
# 0                  831334.104262
# 1                  825511.298092
# 2                  825585.617904
# 3                  823813.817877
# 4                  820471.026426
# 5                  820913.969506
# 6                  822415.142175
# 7                  824308.628675
# 8                  824988.326469

# %%
df.describe()
# Out:
#        test_size  LinearRegression_score  DecisionTreeRegressor_score  \
# count   9.000000                9.000000                     9.000000
# mean    5.000000                0.011607                    -0.112228
# std     2.738613                0.000212                     0.227396
# min     1.000000                0.011314                    -0.630663
# 25%     3.000000                0.011525                    -0.154672
# 50%     5.000000                0.011571                    -0.016233
# 75%     7.000000                0.011669                     0.035546
# max     9.000000                0.011916                     0.060710
#
#        RandomForestRegressor_score  GradientBoostingRegressor_score  \
# count                     9.000000                         9.000000
# mean                     -0.043762                         0.041081
# std                       0.102888                         0.001135
# min                      -0.233575                         0.039738
# 25%                      -0.101294                         0.040488
# 50%                      -0.009848                         0.040824
# 75%                       0.035896                         0.041043
# max                       0.060192                         0.043734
#
#        LinearRegression_MSE  DecisionTreeRegressor_MSE  \
# count              9.000000               9.000000e+00
# mean          849712.760434               9.559644e+05
# std             3953.410489               1.944417e+05
# min           845726.395481               8.165755e+05
# 25%           847413.327466               8.297735e+05
# 50%           849345.726314               8.694754e+05
# 75%           850409.682035               9.900379e+05
# max           858995.382068               1.400949e+06
#
#        RandomForestRegressor_MSE  GradientBoostingRegressor_MSE
# count               9.000000e+00                       9.000000
# mean                8.971633e+05                  824371.325709
# std                 8.691416e+04                    3219.900309
# min                 8.170263e+05                  820471.026426
# 25%                 8.294723e+05                  822415.142175
# 50%                 8.640122e+05                  824308.628675
# 75%                 9.442704e+05                  825511.298092
# max                 1.059800e+06                  831334.104262

# %% [markdown]
# ### 최종 모델 선택

# %%
X = train[["year", "day", "hour", "weekday"]]
y = train["공급량"]

i = 1

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                   test_size = i / 10,
                                                   random_state = 77)

model = DecisionTreeRegressor()
model.fit(X_train, y_train)
pred = model.predict(X_test)

# 결정계수 확인
print("학습용 : {}, 테스트용 : {}".format(10 - i, i))
print("학습용 데이터 결정계수: {:.3f}".format(model.score(X_train, y_train)))
print("테스트 데이터 결정계수: {:.3f}".format(model.score(X_test, y_test)))
print("MSE :", mean_squared_error(y_test, pred))
print()
    
# model.feature_importances_
# Out:
# 학습용 : 9, 테스트용 : 1
# 학습용 데이터 결정계수: 0.199
# 테스트 데이터 결정계수: 0.061
# MSE : 816575.5151588012

# %%
submission = pd.read_csv('../CSV/가스공급량 수요예측 모델개발 data/sample_submission.csv')

# %%
submission.head(3)
# Out:
#           일자|시간|구분  공급량
# 0  2019-01-01 01 A    0
# 1  2019-01-01 02 A    0
# 2  2019-01-01 03 A    0

# %%
test_x = test[["year", "day", "hour", "weekday"]]
pred = model.predict(test_x)
submission["공급량"] = pred

# %%
pred
# Out:
# array([ 494.74      ,  378.35128571,  308.59383333, ..., 1068.20209091,
#        1403.82061538, 1379.48353846])

# %%
submission.head(3)
# Out:
#           일자|시간|구분         공급량
# 0  2019-01-01 01 A  494.740000
# 1  2019-01-01 02 A  378.351286
# 2  2019-01-01 03 A  308.593833

# %%
submission.tail(3)
# Out:
#               일자|시간|구분          공급량
# 15117  2019-03-31 22 H  1068.202091
# 15118  2019-03-31 23 H  1403.820615
# 15119  2019-03-31 24 H  1379.483538

# %%
submission.to_csv("../CSV/Submission/01_base_model.csv", index = False)
